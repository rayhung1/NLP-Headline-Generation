# %% [markdown]
# # 1. Setup

# %%
# install packages
# !pip install -q transformers==4.37.2
# !pip install -q sentencepiece
# !pip install -q evaluate
# !pip install -q tensorflow==2.15
# !pip install -q rouge_score
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 23.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for rouge_score (setup.py) ... done

# %%
# import libraries
import os
import re
import numpy as np
import pandas as pd
import evaluate

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from transformers import T5Tokenizer, TFT5ForConditionalGeneration

# %%
import time

# %%
# mount Colab to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# verify data exists in Google Drive dir
# !ls 'drive/My Drive/W266/Final Project'
# Out:
#  model_checkpoints	     test_pairs.csv    W266_Final_Project_Data_Cleanup.ipynb
# 'old dataset split'	     train_pairs.csv   W266_Final_Project_Pegasus_Ray.ipynb
#  reddit_subset_cleaned.csv   valid_pairs.csv  ' W266_Final_Project_T5_Dipika.ipynb'

# %% [markdown]
# # 2. Load Data

# %%
# load clean Reddit ds
pd.set_option('display.max_colwidth', None)

df = pd.read_csv('drive/My Drive/W266/Final Project/reddit_subset_cleaned.csv')

df.head(3)
# Out:
#                                                                                                        title  \
# 0  google is invasive nonanonymized ad targeting a quick confirmation of previously suspected privacy issues
# 1                         potential job in web analytics need to analyze some data what are they looking for
# 2                                         how to identify which google analytics account is tracking my site
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      post
# 0  i am cross posting this from rcyberlaw hopefully you guys find it as interesting as i didit deals with google analytics so quite awhile ago i ordered a papa john is pizza online my job largely involves looking at ads that appear online so afterwards i was quick to notice i was getting a lot of papa johns ads especially at night being served through a google owned company doubleclick media yesterday one of these ads popped up again on youtube a place that typically serves using the adwords program not doubleclick so i decided to copy the url for those not in the advertising field making full use of google is analytics tool means that certain information about the advertising campaign is leaked in the url so let is break it apart gt heresscs hereampadurl first off we see sscs sscs is doubleclick is redirect variable so rather than directly serving adwords ads they overrode it to serve through doubleclick then redirect through what would otherwise be an adwords link this is tighter integration than is generally seen with adwordsdoubleclick the interesting part is the end variables utm_sourcegooglenetworkamputm_mediumdisplaycpcamputm_campaigngoogleremarketing displaycpcgooglenetwork confirmation that doubleclick is now more finely integrated with adwords googleremarketing huh let is take a look at the definition for remarketing gtusing past campaign information to target a particular message to an audience while in the past behavioral targetting has largely been based on the sum of your use this is an interestingthough no doubt more widespread than is known change in that explicitly targeting old customers though a massive network of sites just thought i would put this out there i am sure it is not new to a lot of people but at least to me it was interesting to see concepts like this actually put into practice on such a large scale ps i did a quick survey across several thousand domains and for the record right now the most common external resource locations on the internet aregoogle owned is bolded pageadgooglesyndicationcom googleadsgdoubleclicknet edgequantservecom addoubleclicknet bscorecardresearchcom smdnnet dgspecificclicknet viewatdmtcom ajaxgoogleapiscom partnergoogleadservicescom that is a lot of data
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        i decided grad school physics was not for me and i am branching out into the job market a web analytics place is interested in me and i am interested in any kind of data analysis the exercise is to use a comparison of three or more months of data to prepare a to slide powerpoint presentation of any significant information about site visitors what they are doing how they arrive at our site that we could use to improve site performance as an acquisition source he said i should notell a story this is a field i am unfamiliar with so i am looking for any basic tips common pitfalls and expectations thanks i am quite familiar with data analysis in general
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          hey all my gf is having trouble with ga and has not gotten any response in days from posting in the google help forums so i figure i would try here question as follows i have a client that we coded a website for and google analytics was plugged into it we would like to look at the statistics for the site and no one can identify what account is associated with the tracking code that is embedded i have pulled the user account number from the source code i am just not sure how to identify what the login associated with it is can anyone help this is a fairly urgent request thanks in advance for any help

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   25000 non-null  object
#  1   post    25000 non-null  object
# dtypes: object(2)
# memory usage: 390.8+ KB

# %%
prefix = 'create headline for post: '
pairs = []

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    post = row['post']
    title = row['title']
    pairs.append({'post': prefix + post, 'title': title})

print(pairs[0])
# Out:
# {'post': 'create headline for post: i am cross posting this from rcyberlaw hopefully you guys find it as interesting as i didit deals with google analytics so quite awhile ago i ordered a papa john is pizza online my job largely involves looking at ads that appear online so afterwards i was quick to notice i was getting a lot of papa johns ads especially at night being served through a google owned company doubleclick media yesterday one of these ads popped up again on youtube a place that typically serves using the adwords program not doubleclick so i decided to copy the url for those not in the advertising field making full use of google is analytics tool means that certain information about the advertising campaign is leaked in the url so let is break it apart gt heresscs hereampadurl first off we see sscs sscs is doubleclick is redirect variable so rather than directly serving adwords ads they overrode it to serve through doubleclick then redirect through what would otherwise be an adwords link this is tighter integration than is generally seen with adwordsdoubleclick the interesting part is the end variables utm_sourcegooglenetworkamputm_mediumdisplaycpcamputm_campaigngoogleremarketing displaycpcgooglenetwork confirmation that doubleclick is now more finely integrated with adwords googleremarketing huh let is take a look at the definition for remarketing gtusing past campaign information to target a particular message to an audience while in the past behavioral targetting has largely been based on the sum of your use this is an interestingthough no doubt more widespread than is known change in that explicitly targeting old customers though a massive network of sites just thought i would put this out there i am sure it is not new to a lot of people but at least to me it was interesting to see concepts like this actually put into practice on such a large scale ps i did a quick survey across several thousand domains and for the record right now the most common external resource locations on the internet aregoogle owned is bolded pageadgooglesyndicationcom googleadsgdoubleclicknet edgequantservecom addoubleclicknet bscorecardresearchcom smdnnet dgspecificclicknet viewatdmtcom ajaxgoogleapiscom partnergoogleadservicescom that is a lot of data', 'title': 'google is invasive nonanonymized ad targeting a quick confirmation of previously suspected privacy issues'}

# %%
# Let's create some splits
np.random.shuffle(pairs)
num_valid_samples = int(0.10 * len(pairs))
num_train_samples = len(pairs) - 2 * num_valid_samples #allocating 80% of dataset for training

train_pairs = pairs[:num_train_samples]
valid_pairs = pairs[num_train_samples : int(num_train_samples + num_valid_samples * 1.5)]
test_pairs = pairs[int(num_train_samples + num_valid_samples * 1.5):]


print(f"{len(pairs)} total pairs")
print(f"{len(train_pairs)} training pairs")
print(f"{len(valid_pairs)} validation pairs")
print(f"{len(test_pairs)} test pairs")
# Out:
# 25000 total pairs
# 20000 training pairs
# 3750 validation pairs
# 1250 test pairs

# %%
# Save splits to separate csv files, to load only part at a time later
train_file = 'drive/My Drive/W266/Final Project/train_pairs.csv'
valid_file = 'drive/My Drive/W266/Final Project/valid_pairs.csv'
test_file = 'drive/My Drive/W266/Final Project/test_pairs.csv'

pd.DataFrame(train_pairs).to_csv(train_file, index=False)
pd.DataFrame(valid_pairs).to_csv(valid_file, index=False)
pd.DataFrame(test_pairs).to_csv(test_file, index=False)

# %%
# Display the first few items of each list
print("Training pairs:")
print(train_pairs[:5])

print("\nValidation pairs:")
print(valid_pairs[:5])

print("\nTest pairs:")
print(test_pairs[:5])
# Out:
# Training pairs:
# [{'post': 'create headline for post: hello i am working with classification and regression using a dataset about movies the problem is i have too many features in my dataset and it makes my neural network overfit pretty fast but i cannot remove these features because i am trying to study their influence in my classificationregression methods one thing i am trying to do is to use autoencoders to try to create a new representation of my data in a smaller dimension the problem is no matter how big i have tried some configuration of networks my network is my autoencoder cannot seem to learn even in the train data as i was testing how to build this autoencoder i was trying to make it overfit so i could reduce complexity later and try to balance the training accuracy with the validation accuracy but i could not do this i would like to know what am i doing wrong or if there are any tips that you could give me to make it work better describing my dataset my dataset is about movies some of its features are things like budget launching year launching month imdb rating etc these are features that are not binary i think there are to features like this the rest of the features are just binary features like if the movie is an action movie or a horror movie there are many features like this as many as of them so you can visualize it as something like this imdbid imdb rating budget horror action other feature tt one of the issues is that i do not have many training examples but this should be a problem for generalizing it not to overfit it i think this data is being normalized using sklearn is minmaxscaler to put all features between and describing my network i have tried many versions of this network but it is a feedforward neural network that receives data pass the data to a smaller layer and then comes back to a layer the same size as the number of features of my dataset it is something like this gt gt gt gt i have tried many versions of this some shallower others deeper some more complex other simpler most of these networks i obtain an accuracy of i notice that my loss keeps going down but my accuracy does not increase every time i am using keras this network uses the sequential model and dense layers i am using mse as my loss function and rmsprop as my optimizer with its default values each layer of my network is being activated by relu function except the last one which i do not apply any activation i have tried to use other loss functions like binary crossentropy and categorical crossentropy but i have used these for classification problems before and as i understand they are not well suited for this problem if i am wrong feel free to correct me thank you for the help', 'title': 'help wanted cannot make autoencoder learn representation'}, {'post': 'create headline for post: hi everyone i am pretty new at this stuff especially with kaggle and i am trying to activate a conda environment with the conda activate command however it comes out with this error commandnotfounderror your shell has not been properly configured to use conda activate to initialize your shell run conda init ltshell_namegt currently supported shells are bash fish tcsh xonsh zsh powershell see conda init help for more information and options important you may need to close and restart your shell after running conda init note you may need to restart the kernel to use updated packages i have tried the conda init command with all of the supported shell but it does not change anything how can i activate my environment thanks', 'title': 'how do i activate a conda environment in kaggle'}, {'post': 'create headline for post: hi all i wanted to share this this really informative slide set i found thanks to hacker news on basic machine learning concepts created by google engineer jason mayes not only are the concepts wellexplained and brief they are also beautifully designed and aesthetically pleasing he divides the slides to blue and green ones where the blue are optional as  ...
#
# Validation pairs:
# [{'post': 'create headline for post: hello i graduated at an unknown state school in political science and economics dual major no math with a gpa recently i have been looking into learning more about data and analytics i am fortunate enough that i landed a job with the state government as a data analyst and am using a little bit of python for basic data manipulation automating pivot tables transforming and manipulating dataframes stuff just beyond excel i have been utilizing python much more recently and am enjoying getting better and better at it i am also learning about powerbi with my job for data visualization and manipulation i have only taken one formal class in python where we cleaned data and made some visualizations so by rdatascience standards i am quite new to all of this but doing these tasks have made me more and more interested in learning these skills i always thought stem was quite dreadful but when you use stem in an area where you have a passion for me it is politics and public policy these skills become incredibly exciting so i ask you what courses should i take to better pursue these skills i have been looking at some masters in data science and data analytics programs but i would like to take some more time working and learning before i commit to a masters degree i have also been thinking on going to my local cc and taking some math stats and cs courses to get a better background what courses would be good for specializing in data should i go back to university and get a degree in math stats cs or something else i am thinking on enrolling in calc because honestly getting an undergrad in econ without the calc was pretty painful because i felt so limited i honestly want to get calc just because i honestly enjoy math and because i really enjoyed game theory so i would like to really understand game theory econometrics and public economics maybe there are some interesting applications with ds thanks', 'title': 'pursuing ds with no stem background advice for a recent undergrad'}, {'post': 'create headline for post: hi there first off if i am not in the right place to ask this question please let me know and i will remove the post i thought this would be a good place to ask but am not sure as mentioned in the question i am about to graduate and start applying for jobs i have noticed that a lot of applications ask for a link to your personal github so i have been updating it to make it more professional i only have no experience in what is expected i have created my profile as can be seen below is this ok is there anything missing is this too much information any and all help and critique will be appreciated', 'title': 'i just currently finishing my msc and am about to enter the job market is my github profile ok like this or is this too cheesy'}, {'post': 'create headline for post: i am a lead data scientist on a portfolio of projects i have a small team and things have been going well and i mostly got positive feedback i have been working closely with a data engineer on one of those projects who wanted to be a data scientist he has finally gotten a goahead by the management i should naturally be the person this guy reports to as i manage all junior data scientists that work on this project management naturally suggested that few days later my manager told that upon further consideration and some feedback he would like someone else to manage this guy some new guy that just started at the company reason i was given was really lame like the new guy works same hours pm as the former data engineer and i work pm obviously that is bs people i manage work from all over the country and range of hours i am kind of annoyed because this data engineer that is now a data scientist and i had a really good working relationship or so i thought it is obvious to me that he specifically requested for me not to manage him for some reason it would be nice to know the reason so that i can learn from it the company culture is kind of ...
#
# Test pairs:
# [{'post': 'create headline for post: so i am preparing a portfolio of my work in r i just wrapped up a pager about using predictive analysis to mitigate insurance claim losses by flagging claims based on a number of characteristics i have also performed some forecasting for revenuesalesgdp my question is where i can find a large dataset about something preferably related to business somehow where i can use analytics to reduce costs like before maximize profits etc i would like to be able to conduct a wide range of analyses on the data as well basically i want to show off a lot that i know in a comprehensive report i can always make my own data but that is not as fun and just feelswrong any suggestions', 'title': 'large sample datasets to showcase skills in r'}, {'post': 'create headline for post: ultimately what matters is which one will help me get into a masters program i am finishing my bachelors have a solid understanding of most ds skills and want to develop skills for the manufacturing industry i currently have one really good research project done with another one starting for my last semester and one really solid reference soon to be i can internship at a small company and do basically whatever i want like an rnn model for forecasting demand inventory management etc i also have the option of working with a professor in the realm of a project related to machine learning but an area that is not as useful to my interests the only reason i would consider it is because i get a solid reference from doing this should i go for a third reference and not as related research project or should i go for a paid internship and develop practical projects i can put on a cv i am leaning the internship pretty hard right now as having more work experience with my specialization seems to help me if i apply for a masters that has manufacturing data science in mind', 'title': 'internship vs research opportunity'}, {'post': 'create headline for post: i have been trying to use the alphago zero paper as a blueprint for a solver however a very big difference between go and is that go is easy to turn into a simple classification problem win or loss for the current player whereas is fundamentally different a way of turning into a classification problem would be to train a neural network to predict the likelihood of the current board reaching however i do not really like this approach because it will not ever reach unless it makes incremental progress on the way there and more importantly i would like it to maximize the score as an end goal see how far it can go i could train it to reach then then then incrementally by reusing the previous network as a starting point but that seems to be way too vulgar and not encapsulating what i want it to learn the other approach would be to avoid classification to begin with and simply predict the final score instead of a value it would be anywhere on the interval my question is whether using the neural network to approximate the score in this way is something that is normally done or if there are inherent problems with it the other approach i was thinking about was training the neural network to take in two games and predict which one will score higher this would be the sort of classic classification problem neural networks are known for but it seems a bit less natural for example if one game loses then the other game would just say i won and terminate and if you wanted it to play normally single player there might not really be a good way to do it you could always have the other board be the same board that might do the trick any thoughts', 'title': 'reinforcement learning approach to'}, {'post': 'create headline for post: hi i am new to reinforcement learning and i am trying to make my own implementations of algorithms such as dqn ac ac ppo and testing them on some atari gamespong breakout space invaders etc using openai gym i made a dqn implementation and i trained it on floydhub it is very convenient and b ...

# %%
# File paths for the split CSV files
train_file = 'drive/My Drive/W266/Final Project/train_pairs.csv'
valid_file = 'drive/My Drive/W266/Final Project/valid_pairs.csv'
test_file = 'drive/My Drive/W266/Final Project/test_pairs.csv'

# Load the CSV files into lists of dictionaries
train_pairs = pd.read_csv(train_file).to_dict('records')
valid_pairs = pd.read_csv(valid_file).to_dict('records')
test_pairs = pd.read_csv(test_file).to_dict('records')

# Display the first few items of each list
print("Training pairs:")
print(train_pairs[:5])

print("\nValidation pairs:")
print(valid_pairs[:5])

print("\nTest pairs:")
print(test_pairs[:5])
# Out:
# Training pairs:
# [{'post': 'my goal is to detect an object that is being flashed in front of a camera therefore the input is a video converted into images frames and the sequence matters i am trying to figure out how to go about training it usually video object detection algorithms detect objects in each frame my problem is that the objects i am trying to classify are similar and the object is not fully visible in any single frame because of a hand holding it in order to correctly tell what the object is you have to look at multiple frames i found which looks at the data sequentially but i am not sure how to map it to my situation anyone else knows about any implementations of a similar problem or potential ways of solving it', 'title': 'video object detection detecting object in the video frames sequentially'}, {'post': 'hi everyone for my master is thesis at the vrije universiteit amsterdam i am researching the environment for it professionals to report wrongdoing related to software examples of wrongdoing related to software are privacy and security issues discrimination happening within the software eg favoring certain users by an algorithm or allowing hate speech against specific user groups enabling fraud or corruption endangering someone is health and safety eg motivating addictive behavior triggering depressing thoughts and damaging the environment eg algorithms with too many co emissions if you are an it professional eg software engineer software tester product owner software consultant data scientist cs researcher please help me out by filling out the survey it takes minutes to complete thanks', 'title': 'reporting wrongdoing related to software'}, {'post': 'hello i am a postgrad in neuroscience and this is my first time using ml for my thesis the basis of my project is to compare the accuracy of random forest svm and decision trees on clinical prediction of depression with that of logistic regression based on brain imaging measures fractional anisotropy and mean diffusivity of white matter tracts with a sample size of around k to k people so far i am a bit overwhelmed and i am sorry if this question seems naïve but i was wondering how to handle missing values and outliers from what i understand each model has different methods impute data delete rows etc that fit best but i am still not sure i feel confident enough to understand the nuances of it so i was considering to just delete the rows with missing data and winsorizing outliers is there a better alternative given my notsodeep knowledge background thank you', 'title': 'missing values and outliers question'}, {'post': 'hi i am working on a project for my portfolio trying to predict employee turnover binary via logistic regression there are about variables in the dataset that could potentially be related to turnover in my experience i studied psychological science it is best practice to only include variables in your model that you have reason to believe are related to your outcome variable for example through previous research or subject matter expertise however i see in youtube tutorials of logistic regression people just throwing every variable directly in the model should i be exploring the relationship between each possible predictor and the outcome variable to establish a relationship first before building my model for example via running a chisquare of independence test on a potential categorical predictor and my outcome variable or is this redundant as the logistic regression model will sus out the nonsignificant predictors tldr what are the best practices for feature selection in logistic regression should i do exploratory data analysis for every possible predictor before building my model to rationalize their inclusion in the model or just throw them all in thank you for bearing with me', 'title': 'to explore relationships between predictors and outcome variable before building model or not'}, {'post': 'i must warn before i begin that i am coming from the hard science sp ...
#
# Validation pairs:
# [{'post': 'i just came up with a data sciencey project idea but i need help with the math side of it i will take studies that have found a correlation between cannabis use in undeveloped brains and decreased cognitive capacity and for the sake of this example i will input variables average frequency of consumption and quantity consumed i will take this through a python script and i will output a mathematical function that connects two percentages the probability first percentage x that you will be y less capable than the average nonsmoker person in either shortterm memory attention span etc the problem is i know literally no statistics so i am kinda struggling with the math side is this what you would call a linear regression what is the actual algorithm for outputting this mathematical function i first thought i would have to just do some sort of arithmetic mean but it got more complicated when you had more values for example i can have this data set a bigger sample would give more accuracy but i am gonna give a sample of so this example is easier let f be the average frequency of use in days how much days do they wait in between smoke sessions let q be the average quantity they consume in each session in grams or whatever unit of measure does not matter user f q user f q user f q each user will also have a variable representing how much less capable they are than the average person on a certain mental task in reality i am probably gonna have a list of variables for each user so i compute a separate mathematical function for each mental ability memory attention span etc but for the sake of this example let is say they have just one more variable representing how worse they are from the average person at attention span let it be a user a user a user a now i have to use all this data to compute a mathematical function f s gt s f q p f q are from r p is from which takes in the percentage of probability that the output is gonna happen as well as f and q and outputs the percentage decrease in attention span from the normal person basically a now that i think of it it should work in reverse too inputting the percentage decrease and outputting the probability that will happen so this function also has to be bijective actually it is not bijective per se because i just reverse a and p i add a in the domain set s and take out p in the output anyway now what i need help with is computing the larger function that takes in two variables and outputs the function f and that larger function is fed before two lists of variables to have the proper data that will be the script i will write i am stumped because it is taking in three lists of variables and outputs if it was just two outputting it would be easier for example user f a user f a user f a it is way easier to do it now having to output just a if i input or i know what i am going to get if i output anything else between and i just have to find out the relation between the two closest variables from to f halved and a tripled this would mean that most likely if f quarters then a would be multiplied by if f is divided by a would be multiplied by etc that is for any variable between and between and i do the same with the other data is this a correct approach either way if you also have to add the output p besides the output a i am stuck then you also add the input q and i am even more stuck so what do i have to do i know how to compute derivatives and to work with matrices and determinants in case that is needed', 'title': 'how do i compute this percentage from the available data is this a linear regression data science project'}, {'post': 'my client comes up with a huge volume of reddit data and she wants to know what people are talking about a particular product she is expecting some insights for their next product planning the data is around k conversations for just days after removing promo and spam the dead line is just a few days ahead now how should we do it the team is reading each  ...
#
# Test pairs:
# [{'post': 'some background i have been learning python for over a year now and i know some sql a bit of r and i have completed some small projects using data science data engineering practices i also know how to work in excel but i do not really have experience using databases i am totally willing to make the time and money investment in something like a bootcamp and i have the means to do fulltime training but i do not want to do this if there is a better faster way to get into the industry what i really want to know is what can i do that will get me a job in the field asap is there some specific bootcamp that will make this happen if so what are the best bootcamps or some particular tech skill i could learn that would basically guarantee that i am hireable very soon if i something like learned microsoft sql server or tableau and given my other skills would this be likely to get me hired i have been looking into bootcamps like thinkful springboard and data application lab the concern i have about these is actually that i already know a lot of the stuff they teach and i am worried that these will be a waste of time and not elevate me to where i want to be i also worry about it taking months to complete these programs as they estimate i would like to be finished in no more than about months thoughts', 'title': 'i want to transition into the data scienceanalyst or related field rather than asking whether i should choose a particular boootcamp or learn some language i would like to hear opinions on what path should i choose that will land me a job of some kind in the field as soon as possible'}, {'post': 'hi all i have created a python module to extract sngrams which is different from traditional ngrams as it embodies linguistic syntactic trees thus making it less arbitrary than traditional ngrams as it goes without saying quality of input feature affects model performance this will help you improve your model accuracy even further built on language models of spacy it can help especially for text classification information extraction query understanding machine translation question answering systems below is an example from sngramextractor import sngramextractor ampxb sngram_objsngramextractortextmeta_tagoriginaltrigram_flagyes texteconomic news have little effect on financial markets outputsngram_objget_sngram printtext print isngram bigramoutput isnbigram print isngram trigramoutput isntrigram economic news have little effect on financial markets sngram bigram cloud_every has_cloud lining_a lining_silver has_lining sngram trigram has_lining_silver ampxb textevery cloud has a silver lining outputsngram_objget_sngram printtext print isngram bigramoutput isnbigram print isngram trigramoutput isntrigram ampxb every cloud has a silver lining sngram bigram cloud_every has_cloud lining_a lining_silver has_lining sngram trigram has_lining_silver ampxb pypi', 'title': 'psngram linguistic features for improving machine learning and deep learning model accuracy for the first time in python new release'}, {'post': 'i am looking at some of the modeling programs the company has been using and there are options to smooth binned data layered linear on bin linear on avg linear on log avg and variable gradient are these methods commonly used in any algorithms i am not sure how i would implement it into r ampxb variable gradient is the most confusing it groups data from neighboring bins with a bin factor being determined the level of smoothing is determined by the radius all bins contribute to the calculation of the bin factor with decreasing weight as the distance from the target bin increases the weight is equal to radius distance radius ampxb once you calculate the overall factor a calculation is performed for each bin weighted by an exposure with various radii and a selected credibility level the calculation that yields the largest distance from is then selected as the factor to be used for that bin ampxb over multiple iterations of the model ...

# %% [markdown]
# # 3. Preprocessor and Data Generator

# %%
def preprocess_data(pairs, tokenizer, model, max_length=128):
    post_text = [post for post, title in pairs]
    post_encoded = tokenizer.batch_encode_plus(
        post_text,
        max_length=max_length,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        return_tensors='tf'
    )

    post_input_ids = np.array(post_encoded["input_ids"], dtype="int32")
    post_attention_masks = np.array(post_encoded["attention_mask"], dtype="int32")

    title_text = [title for post, title in pairs]
    title_encoded = tokenizer.batch_encode_plus(
        title_text,
        max_length=max_length,
        padding='max_length',
        truncation=True,
        return_tensors='tf'
    )

    label_ids = np.array(title_encoded['input_ids'])
    decoder_input_ids = model._shift_right(label_ids)

    return [post_input_ids, post_attention_masks, decoder_input_ids], label_ids

# %%
class SummarizeDataGenerator(tf.keras.utils.Sequence):

    def __init__(self,
                 tokenizer,
                 model,
                 n_examples,
                 data_filename,
                 max_length=128,
                 batch_size=16,
                 shuffle=True):

        self.tokenizer = tokenizer
        self.model = model
        self.n_examples = n_examples
        self.data_filename = data_filename
        self.max_length = max_length
        self.batch_size = batch_size
        self.shuffle = shuffle

        # Initialize row order, call on_epoch_end to shuffle row indices
        self.row_order = np.arange(1, self.n_examples+1)
        self.on_epoch_end()

    def __len__(self):
        # Return the number of batches in the full dataset
        return self.n_examples // self.batch_size

    def __getitem__(self, idx):
        batch_start = idx * self.batch_size
        batch_end = (idx + 1) * self.batch_size

        # Indices to skip are the ones in the shuffled row_order before and
        # after the chunk we'll use for this batch
        batch_idx_skip = self.row_order[:batch_start] + self.row_order[batch_end:]
        df = pd.read_csv(self.data_filename, skiprows=batch_idx_skip)

        pairs = df[['post', 'title']].values.astype(str).tolist()

        batch_data = preprocess_data(
            pairs,
            self.tokenizer,
            self.model,
            self.max_length
        )

        return batch_data

    def __call__(self):
        for i in range(self.__len__()):
            yield self.__getitem__(i)

            if i == self.__len__()-1:
                self.on_epoch_end()

    def on_epoch_end(self):
        if self.shuffle:
            self.row_order = list(np.random.permutation(self.row_order))

# %% [markdown]
# # 4. Pretrained model
#
# ---

# %%
# Load the pretrained tensorflow model

model_name = 't5-base'
t5_tokenizer = T5Tokenizer.from_pretrained(model_name)
t5_model = TFT5ForConditionalGeneration.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:240: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFT5ForConditionalGeneration.
#
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %%
# Create the data generators for train and validation data, tensorflow version

max_length = 32
batch_size = 16

train_data_generator = SummarizeDataGenerator(
    tokenizer=t5_tokenizer,
    model=t5_model,
    n_examples=len(train_pairs),
    data_filename=train_file,
    max_length=max_length,
    batch_size=batch_size
)

valid_data_generator = SummarizeDataGenerator(
    tokenizer=t5_tokenizer,
    model=t5_model,
    n_examples=len(valid_pairs),
    data_filename=valid_file,
    max_length=max_length,
    batch_size=batch_size
)

# %%
def build_t5_training_wrapper_model(t5_model, max_length, learning_rate=0.0005):
    input_ids = layers.Input(shape=(max_length), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(max_length), dtype=tf.int32, name='attention_mask')
    decoder_input_ids = layers.Input(shape=(max_length), dtype=tf.int32, name='labels')

    t5_logits = t5_model(input_ids, attention_mask=attention_mask, decoder_input_ids=decoder_input_ids)[0]

    model = tf.keras.models.Model(inputs=[input_ids, attention_mask, decoder_input_ids],
                                  outputs=[t5_logits])
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    return model

# %%
model_wrapper = build_t5_training_wrapper_model(t5_model, max_length, learning_rate=0.0005)

# %%
# add a model checkpoint callback to save
# the trained model weights after each epoch.

checkpoint_dir = 'drive/My Drive/W266/Final Project/model_checkpoints/'
checkpoint_filepath = checkpoint_dir + 't5_reddit_weights.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True)

# %%
# Now call .fit on the model_wrapper, passing in the data generators and the
# model checkpoint callback

model_wrapper.fit(train_data_generator,
                  validation_data=valid_data_generator,
                  epochs=3,
                  callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/3
# 1250/1250 [==============================] - 609s 432ms/step - loss: 1.5393 - accuracy: 0.7336 - val_loss: 1.3589 - val_accuracy: 0.7528
# Epoch 2/3
# 1250/1250 [==============================] - 532s 426ms/step - loss: 1.3060 - accuracy: 0.7569 - val_loss: 1.3417 - val_accuracy: 0.7542
# Epoch 3/3
# 1250/1250 [==============================] - 527s 422ms/step - loss: 1.1636 - accuracy: 0.7728 - val_loss: 1.3531 - val_accuracy: 0.7543

# %% [markdown]
# # 5. Evaluation

# %%
test_pairs[0]
# Out:
# {'post': 'some background i have been learning python for over a year now and i know some sql a bit of r and i have completed some small projects using data science data engineering practices i also know how to work in excel but i do not really have experience using databases i am totally willing to make the time and money investment in something like a bootcamp and i have the means to do fulltime training but i do not want to do this if there is a better faster way to get into the industry what i really want to know is what can i do that will get me a job in the field asap is there some specific bootcamp that will make this happen if so what are the best bootcamps or some particular tech skill i could learn that would basically guarantee that i am hireable very soon if i something like learned microsoft sql server or tableau and given my other skills would this be likely to get me hired i have been looking into bootcamps like thinkful springboard and data application lab the concern i have about these is actually that i already know a lot of the stuff they teach and i am worried that these will be a waste of time and not elevate me to where i want to be i also worry about it taking months to complete these programs as they estimate i would like to be finished in no more than about months thoughts',
#  'title': 'i want to transition into the data scienceanalyst or related field rather than asking whether i should choose a particular boootcamp or learn some language i would like to hear opinions on what path should i choose that will land me a job of some kind in the field as soon as possible'}

# %%
for test_input_text in ['Hello all - I have an upcoming live case interview at CVS for their data science role. Can yall please share your experience of how the interview went? \
                        Did it involve quantitative analysis or was it just qualitative in nature? \
                        Did they supplement the discussion with some data? \
                        Were they expecting a technical ML solution? Or did they only want to guage the candidates thought process and structured communication?']:

    test_inputs = t5_tokenizer([prefix + test_input_text], return_tensors='tf')
    test_output_ids = t5_model.generate(test_inputs['input_ids'])

    print([t5_tokenizer.decode(out_ids, skip_special_tokens=True,
                               clean_up_tokenization_spaces=False) for out_ids in test_output_ids])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/tf_utils.py:838: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ['upcoming live case interview at CVS']

# %%
#load the saved model weights
checkpoint_dir = 'drive/My Drive/W266/Final Project/model_checkpoints/'

checkpoint_filepath = checkpoint_dir + 't5_reddit_weights.03-0.75.hdf5'
model_wrapper.load_weights(checkpoint_filepath)

# %%
# Still works?
for test_input_text in ['Hello all - I have an upcoming live case interview at CVS for their data science role. Can yall please share your experience of how the interview went? \
                        Did it involve quantitative analysis or was it just qualitative in nature? \
                        Did they supplement the discussion with some data? \
                        Were they expecting a technical ML solution? Or did they only want to guage the candidates thought process and structured communication?']:
    test_inputs = t5_tokenizer([prefix + test_input_text], return_tensors='tf')
    test_output_ids = t5_model.generate(test_inputs['input_ids'])

    print([t5_tokenizer.decode(out_ids, skip_special_tokens=True,
                               clean_up_tokenization_spaces=False) for out_ids in test_output_ids])
# Out:
# ['upcoming live case interview at CVS']

# %%
# Candidates: these are the actual Reddit titles from the test set
EXAMPLES_NUM = 10

test_posts = [t5_tokenizer(item['post'], max_length=512, truncation=True, return_tensors='tf') for item in test_pairs[:EXAMPLES_NUM]]

# Generating output ids for each tokenized post
test_output_ids = [t5_model.generate(post['input_ids'],
                                    num_beams=3,
                                    no_repeat_ngram_size=2,
                                    num_return_sequences=1,  # returns the # of sequences for each post
                                    max_length=128) for post in test_posts]

# %%
t5_model.summary()
# Out:
# Model: "tft5_for_conditional_generation"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  shared (Embedding)          multiple                  24674304
#
#  encoder (TFT5MainLayer)     multiple                  109628544
#
#  decoder (TFT5MainLayer)     multiple                  137949312
#
# =================================================================
# Total params: 222903552 (850.31 MB)
# Trainable params: 222903552 (850.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
EXAMPLES_NUM = len(test_pairs)

print(f"Generating {EXAMPLES_NUM} samples ... ")

# Generate input ids for each tokenized post
test_posts = [t5_tokenizer(item['post'], max_length=512, truncation=True, return_tensors='tf') for item in test_pairs[:EXAMPLES_NUM]]

# Generating output ids for each tokenized post
start_time = time.time()
test_output_ids = [t5_model.generate(post['input_ids'],
                                    num_beams=3,
                                    no_repeat_ngram_size=2,
                                    num_return_sequences=1,  # returns the # of sequences for each post
                                    max_length=128) for post in test_posts]

end_time = time.time()
run_time = end_time - start_time

print(f"Generate Time elapsed: {run_time} seconds.\n")

# initialize list of candidates
candidates = []

# Decode each output in the batch of generated outputs
for out_ids in test_output_ids:
    # Decode each output in the batch of generated outputs
    candidates_batch = [t5_tokenizer.decode(ids, skip_special_tokens=True, clean_up_tokenization_spaces=False) for ids in out_ids]
    candidates.extend(candidates_batch)  # Extend the main candidates list with the batch

# Inspect references list
for idx, candidate in enumerate(candidates):
  print("Candidate #",idx,":\t ",candidate)
  #print("\t",candidate)
# Out:
# Generating 1250 samples ...
# Generate Time elapsed: 7685.047694444656 seconds.
#
# Candidate # 0 :	  what is the best way to get a job in the field of data science
# Candidate # 1 :	  python spacy for ngrams
# Candidate # 2 :	  what is the best way of calculating the weights for a neural network
# Candidate # 3 :	  what is the best way of storing a large amount of data in the retraining process
# Candidate # 4 :	  how do i get the best results out of the mahalanobis dataset
# Candidate # 5 :	  i am a data science intern and ive been looking for feedbacks on my internship
# Candidate # 6 :	  what is the average salary for a data scientist
# Candidate # 7 :	  ms in statistics vs cs for data science
# Candidate # 8 :	  what is the difference between a phd and data science
# Candidate # 9 :	  how do i prepare for a phd in data science
# Candidate # 10 :	  python for data science
# Candidate # 11 :	  what is the best way to get a job in data science
# Candidate # 12 :	  introducing cafi for college sports
# Candidate # 13 :	  what is the best way to automate the ecommerce process
# Candidate # 14 :	  ms in bioinformatics or data science
# Candidate # 15 :	  what is the best way to learn sql for an entry level data analyst
# Candidate # 16 :	  i have a job interview tomorrow and it seems to be the end of the interview
# Candidate # 17 :	  what is the best way to get a job in data science
# Candidate # 18 :	  i am a cs student who wants to get into the data science field but have no idea where to start
# Candidate # 19 :	  ms in data science vs cs for ds
# Candidate # 20 :	  i got an offer for a data analyst position but rescinded my offer
# Candidate # 21 :	  what is the best way to set up an api for your company
# Candidate # 22 :	  what is the future of data science
# Candidate # 23 :	  what is the best way to implement deep learning in a cnn
# Candidate # 24 :	  gradient descent for wordvec
# Candidate # 25 :	  adobe analytics vs python
# Candidate # 26 :	  a question about tensorflow and keras
# Candidate # 27 :	  looking for people to interview for a data science internship
# Candidate # 28 :	  how do i train a neural network with different axes
# Candidate # 29 :	  how do i set up a data flow in google analytics
# Candidate # 30 :	  how do you approach a data science problem
# Candidate # 31 :	  what is the best way to learn deep learning
# Candidate # 32 :	  econ or data science vs cs
# Candidate # 33 :	  keras pytorch implementation of sklearn is not training
# Candidate # 34 :	  what is the best way to do this in rnns
# Candidate # 35 :	  what is the best way to organize and edit a python script in r
# Candidate # 36 :	  what is the best way to prepare for a data science phd
# Candidate # 37 :	  keras pytorch vs gradient descent optimizr
# Candidate # 38 :	  how do you manage your data on a single dataset
# Candidate # 39 :	  what is the difference between a bmc and python and google analytics
# Candidate # 40 :	  econometrics vs data science
# Candidate # 41 :	  what is the future of supercomputers
# Candidate # 42 :	  python vs gpus for nlp
# Candidate # 43 :	  how do you handle nns in python
# Candidate # 44 :	  what is the name of this book
# Candidate # 45 :	  tensorflow on gpus
# Candidate # 46 :	  pytorch inference with flashai
# Candidate # 47 :	  how does a normalization problem work with pytorch
# Candidate # 48 :	  how do you deal with a lot of data in your organization
# Candidate # 49 :	  what is the difference between a senior data scientist and an analyst
# Candidate # 50 :	  pca for a movie genre classification problem
# Candidate # 51 :	  how to organize a data set for people who likes and dislikes the food they eat
# Candidate # 52 :	  i am a software engineer who wants to get into data science
# Candidate # 53 :	  swish vs pytorch for deep learning
# Candidate # 54 :	  customer attrition in aws
# Candidate # 55 :	  i created a python classifier for reddit and it is not working
# Candidate # 56 :	  what is the difference between ds and ml
# Candidate # 57 :	  how do i get my data into one place
# Candidate # 58 :	  how does a decision boundary work in keras
# Candidate # 59 :	  ms in data science
# Candidate # 60 :	  what is the industry like for data science
# Candidate # 61 :	  what is the best way to normalise a dataset of movies
# Candidate # 62 :	  what is the best way to approach this problem
# Candidate # 63 :	  how to get started with data science
# Candidate # 64 :	  what is your typical workflow for a data analyst
# Candidate # 65 :	  looking for a dataset of the first level of government divisions
# Candidate # 66 :	  what is the best way to do this if you have a lot of data but i am not sure how to approach it
# Candidate # 67 :	  what is the best way to store mysql data in a database
# Candidate # 68 :	  how to increase the number of features in a neural network
# Candidate # 69 :	  python keras pretrained pred model for nlp
# Candidate # 70 :	  combining discrete and unbalanced time series
# Candidate # 71 :	  is it possible to use the brave browser to hide your ip address from malicious people
# Candidate # 72 :	  pytorch keras tensorflow
# Candidate # 73 :	  how to train a cnn with only images
# Candidate # 74 :	  what is the best way to learn sql for a python job
# Candidate # 75 :	  what is the best way to get a job as an economist
# Candidate # 76 :	  synthetic datasets
# Candidate # 77 :	  spacy vs tfidf in keras
# Candidate # 78 :	  how do you go about creating a transition matrix in python
# Candidate # 79 :	  what to expect from a data analyst interview
# Candidate # 80 :	  dutch vs python for nlp
# Candidate # 81 :	  r vs python for topic modeling
# Candidate # 82 :	  how to postprocess a cnn with pytorchtensorflow
# Candidate # 83 :	  keras input shape is x y but i am not sure how to do it
# Candidate # 84 :	  how to build a data science portfolio
# Candidate # 85 :	  what are the best tools for a data science project
# Candidate # 86 :	  what is the difference between an algorithm and a decision tree
# Candidate # 87 :	  help with ai to play npc battles
# Candidate # 88 :	  econometrics vs data science
# Candidate # 89 :	  nlp for iphone and python
# Candidate # 90 :	  how much does a data scientist need to know to be good at ml
# Candidate # 91 :	  free webinar on domino ml lab
# Candidate # 92 :	  what is the best way to get into data science
# Candidate # 93 :	  how do i get my tensorflow outputs to work
# Candidate # 94 :	  help with optimizing url with gtm
# Candidate # 95 :	  pytorch keras epochs
# Candidate # 96 :	  how do you go about communicating your data
# Candidate # 97 :	  what is the best way to do a multivariate time series
# Candidate # 98 :	  how do i get better at data science
# Candidate # 99 :	  what is the best way to do this
# Candidate # 100 :	  what is the difference between data science and data analysis
# Candidate # 101 :	  what is the best way to train a neural network to recognize different images
# Candidate # 102 :	  what is the difference between business analytics and data science
# Candidate # 103 :	  i created a ml project to help students who are looking for feedbacks on the project
# Candidate # 104 :	  how do you go about creating a selfcontained data analysis product
# Candidate # 105 :	  mscac vs scotia
# Candidate # 106 :	  what is the best way to store and visualize a lot of data in python
# Candidate # 107 :	  how do i set up a value function for my game console
# Candidate # 108 :	  what is the best way to learn deep learning
# Candidate # 109 :	  what is a good interactive plotting tool
# Candidate # 110 :	  looking for recommendations for a logistic regression model to predict the number of people who bought the product
# Candidate # 111 :	  keras kfold cross validation
# Candidate # 112 :	  autocorrelation for a time series
# Candidate # 113 :	  how do you go about estimating the size of the us population
# Candidate # 114 :	  what is the best way to learn ml from scratch
# Candidate # 115 :	  what is the best way to get into data science with a bsc in applied statistics
# Candidate # 116 :	  etl to predict customer churn
# Candidate # 117 :	  i am a beginner in dl and ive been tasked with tensorflow for pytorch and have no idea where to start
# Candidate # 118 :	  gtm for a website with multiple subdivisions
# Candidate # 119 :	  why is the distribution of the predicted variables so different from the one that i have been working on
# Candidate # 120 :	  ibm watson for image recognition
# Candidate # 121 :	  looking for someone to study ml
# Candidate # 122 :	  what is the difference between neural networks and sigmoid vs python
# Candidate # 123 :	  what are the skills i should focus on for a data science internship
# Candidate # 124 :	  i am a cs student who wants to get into data science
# Candidate # 125 :	  what is the best way to standardise a feature selection model
# Candidate # 126 :	  what is the best way to classify a certain type of keywords
# Candidate # 127 :	  what is the best course for learning ds
# Candidate # 128 :	  udacity ms in data science worth the money
# Candidate # 129 :	  what is the future of data science
# Candidate # 130 :	  keras back propagation with pytorch
# Candidate # 131 :	  help with exploratory data analysis
# Candidate # 132 :	  unsupervised traffic detection
# Candidate # 133 :	  what is the best way to track yolo object detection
# Candidate # 134 :	  how do i create a gradient descent plot with keras
# Candidate # 135 :	  how do you go about adding additional data to your model
# Candidate # 136 :	  how do i track my users based on their behavior
# Candidate # 137 :	  how to get a job in data science
# Candidate # 138 :	  msc data science vs python
# Candidate # 139 :	  looking for someone to help me with a data science project
# Candidate # 140 :	  google tag manager vs python
# Candidate # 141 :	  what is the difference between a cnn and an lstm
# Candidate # 142 :	  i have an offer for a lead data scientist position and msc in ds
# Candidate # 143 :	  what is the best way to prepare for a data science internship
# Candidate # 144 :	  tensorflow keras lstm output is not good
# Candidate # 145 :	  how to check if a dataset is linearly separable
# Candidate # 146 :	  knime vs tableau for freelancers
# Candidate # 147 :	  python how do i assign a classifier to my cnn
# Candidate # 148 :	  what is the best way to do a python based db wrangling
# Candidate # 149 :	  gpus vs keras
# Candidate # 150 :	  pytorch keras tensorflow
# Candidate # 151 :	  what is the best way to learn python for a data analyst
# Candidate # 152 :	  how to backprop my neural network in keras
# Candidate # 153 :	  i am a phd in data science and want to get into the industry
# Candidate # 154 :	  how do i approach this problem
# Candidate # 155 :	  what is the best way to get into the data science field
# Candidate # 156 :	  what is the best way to get a job in data science
# Candidate # 157 :	  python db for a ml project
# Candidate # 158 :	  what is the best way to learn data science
# Candidate # 159 :	  looking for a dataset of product reviews and customer reviews
# Candidate # 160 :	  what are the long term prospects for a data scientist
# Candidate # 161 :	  what is the best way to get a job in data science
# Candidate # 162 :	  what is the best way to create a mlbased trading platform
# Candidate # 163 :	  what is the best way to do word embeddings in python
# Candidate # 164 :	  how do you deal with a data science problem
# Candidate # 165 :	  i am a new data scientist and it is time for me to get my foot in the door
# Candidate # 166 :	  how do i get my data to work in python
# Candidate # 167 :	  how much ml is required for a startup
# Candidate # 168 :	  looking for a good ml project on the topic of robotics
# Candidate # 169 :	  coronavirus evolution
# Candidate # 170 :	  what is the best way to track onsite traffic amp clicks
# Candidate # 171 :	  sklearn covariance matrix
# Candidate # 172 :	  how do i make a recommendation system that is not dependent on the input of the user
# Candidate # 173 :	  how to make a positive impact on society
# Candidate # 174 :	  what is the difference between stats and data science
# Candidate # 175 :	  how do i get my data to work with a cnn
# Candidate # 176 :	  how do i keep my timetamps simple
# Candidate # 177 :	  how do i normalize a large dataset of features
# Candidate # 178 :	  i am a ds intern at london and they asked me to do an msc in deep learning what is the expected outcome
# Candidate # 179 :	  i am a data scientist who wants to help you get started in the field of data science
# Candidate # 180 :	  what internships should i look for
# Candidate # 181 :	  what are some of your favorite data science projects
# Candidate # 182 :	  msc in data science or nlp
# Candidate # 183 :	  predicting stock prices with unseen data
# Candidate # 184 :	  svd and singular value decomposition
# Candidate # 185 :	  python vs r for data science
# Candidate # 186 :	  what is the best approach to gather data for atari games
# Candidate # 187 :	  what is the difference between data science and data analysis
# Candidate # 188 :	  i am a data scientist and ive been tasked with creating videos on the side how to improve the quality of my videos
# Candidate # 189 :	  what are some of the best toolstools for a data scientist
# Candidate # 190 :	  sas vs sql for python and jupyter notebooks
# Candidate # 191 :	  what is the difference between data science and analytics
# Candidate # 192 :	  utms in google analytics
# Candidate # 193 :	  help with a recommendation system
# Candidate # 194 :	  what is the future of data science
# Candidate # 195 :	  i am a software developer who wants to get into the data science world
# Candidate # 196 :	  what is the difference between a keras and tensorflowjs
# Candidate # 197 :	  what is the best way to prepare for a data science job interview
# Candidate # 198 :	  azure docker vs python for data science
# Candidate # 199 :	  how to get a job in data science
# Candidate # 200 :	  how to make this look better in keras
# Candidate # 201 :	  python nlp for text analysis
# Candidate # 202 :	  resume advice for a data science resume
# Candidate # 203 :	  how do you go about presenting your results
# Candidate # 204 :	  uc berkeley ms in data science
# Candidate # 205 :	  what is the difference between a gan and an eli
# Candidate # 206 :	  python vs cs for data science
# Candidate # 207 :	  how to track and track events in ga
# Candidate # 208 :	  pytorch multioutput with keras
# Candidate # 209 :	  what is the best way to do data science in a ml environment
# Candidate # 210 :	  i am a jupyter notebook that uses pytorch and tensorflow
# Candidate # 211 :	  how to build a speaker identification system with gmmubms
# Candidate # 212 :	  what is the best way to learn deep learning
# Candidate # 213 :	  how do i approach this problem
# Candidate # 214 :	  i built a bert app that lets you use jupyter notebooks in pytorch
# Candidate # 215 :	  what is the best ml library for me
# Candidate # 216 :	  what is the best way for me to get a laptop for data science
# Candidate # 217 :	  what is the best way to get hired as a data scientist
# Candidate # 218 :	  what is the best way to model a smooth seasonal signal
# Candidate # 219 :	  what is the difference between data science and machine learning
# Candidate # 220 :	  twitter sentiment analysis
# Candidate # 221 :	  what is the right way to go from a ds role to an msc in data science
# Candidate # 222 :	  what is the best way to add data to a supervised learning model
# Candidate # 223 :	  predicting conversational data
# Candidate # 224 :	  how to set up a cnn in keras
# Candidate # 225 :	  what is the best way to get a job in data science
# Candidate # 226 :	  how much data do you use in your company
# Candidate # 227 :	  what is the best free aws certification for data science
# Candidate # 228 :	  why is the python algorithm used in the paragraph vector so different from the rest of the text
# Candidate # 229 :	  what is the best way to store large amounts of data in a warehouse
# Candidate # 230 :	  pytorch talk on deep learning and nlp
# Candidate # 231 :	  msc in statistics vs cs for a career in data science
# Candidate # 232 :	  pytorch vs tensorflow
# Candidate # 233 :	  i am trying to build a dashboard of content types and theme views but not sure how to do it
# Candidate # 234 :	  i created a dataset of cryptocurrency market data from scratch for kaggle competition
# Candidate # 235 :	  what is the difference between a derivative market and an actuarial field
# Candidate # 236 :	  how do i become a data analyst
# Candidate # 237 :	  dsa vs pca for data science interview
# Candidate # 238 :	  how do i go about comparing two different lead data sets
# Candidate # 239 :	  i am a chartio developer who is looking for people to help me get started with data science
# Candidate # 240 :	  how to do a regression in keras
# Candidate # 241 :	  sfu vs uc berkeley
# Candidate # 242 :	  what is the value of data science
# Candidate # 243 :	  why is the keras pytorch implementation so different from the one that i have been working on
# Candidate # 244 :	  what is the difference between data science and data analytics
# Candidate # 245 :	  what is the best way to learn ml for a beginner
# Candidate # 246 :	  what is the difference between kaggle and uc berkeley for data science
# Candidate # 247 :	  how do i store a specific number of times based on the digits in my cnn
# Candidate # 248 :	  keras is a python package that lets you pick the best bets for you
# Candidate # 249 :	  what is the future of data science
# Candidate # 250 :	  i am unable to find the imdb movie reviews dataset
# Candidate # 251 :	  data science degree or certification program
# Candidate # 252 :	  what is the best way to get into the data science field
# Candidate # 253 :	  what is the best way to organize a large amount of data
# Candidate # 254 :	  i am a business analyst who wants to get python and ml to work with jupyter notebooks
# Candidate # 255 :	  ms in data science vs cs for a phd
# Candidate # 256 :	  how to plot a linear regression with ltbrgt in python
# Candidate # 257 :	  what is the difference between data science and data analysis
# Candidate # 258 :	  what is the best way to get into data science
# Candidate # 259 :	  msba vs mba for data science
# Candidate # 260 :	  how do i add a new layer to my cnn
# Candidate # 261 :	  what is the difference between python and tensorflow
# Candidate # 262 :	  how do you approach this problem
# Candidate # 263 :	  adwords vs organic search
# Candidate # 264 :	  what is the best way to get a job in data governance
# Candidate # 265 :	  how to deal with seasonality in a dsml model
# Candidate # 266 :	  i am a cs student who wants to get into data science
# Candidate # 267 :	  what are some of the things i can do to stay competitive in analyticsdata science
# Candidate # 268 :	  dti for drug discovery
# Candidate # 269 :	  what is the difference between a kpv and an ml model
# Candidate # 270 :	  what is the best way to learn python for data science
# Candidate # 271 :	  what is the purpose of this app
# Candidate # 272 :	  what is the difference between ml and data science
# Candidate # 273 :	  how do i get my data from a single source
# Candidate # 274 :	  what is the best way to get a job in data science
# Candidate # 275 :	  i am a phd student who wants to get into data science but do not know how to do it
# Candidate # 276 :	  how do i find out if my ecommerce product is overindexing
# Candidate # 277 :	  is it possible to play a game like this with tensorflow keras
# Candidate # 278 :	  how to define a nlp problem
# Candidate # 279 :	  what is the difference between a msc in data science and data analytics
# Candidate # 280 :	  i am a python developer who wants to get into the data science field but do not know how to do it
# Candidate # 281 :	  how do you go about creating a data warehousing tool
# Candidate # 282 :	  what are the skills you would recommend for a phd student
# Candidate # 283 :	  how to make the transition to data science
# Candidate # 284 :	  how to use discrete features in a recommendation system
# Candidate # 285 :	  what is the best way to build a predictive model
# Candidate # 286 :	  phd in data science vs ms in statistics
# Candidate # 287 :	  what is the difference between a business analyst and msba
# Candidate # 288 :	  looking for a dataset that contains categorical categories
# Candidate # 289 :	  what is the best way to get a job in data science
# Candidate # 290 :	  what is the best way to measure the number of pixels in a single image
# Candidate # 291 :	  epoch loss in keras
# Candidate # 292 :	  i have a pytorch internship interview tomorrow and it seems to be pretty much the same thing as it was supposed to
# Candidate # 293 :	  how to get into data science with a python degree
# Candidate # 294 :	  what are some good ways to get a data science job in the us
# Candidate # 295 :	  what is a data science career path
# Candidate # 296 :	  what is the best way to get into data science
# Candidate # 297 :	  i am a python developer who wants to get into the data science field but have no experience in the field
# Candidate # 298 :	  what is the difference between data science and data analysis
# Candidate # 299 :	  i am a senior data scientist at my company and ive been in the industry for years and have no idea what to do next
# Candidate # 300 :	  how to get into data science with a bsc in biology
# Candidate # 301 :	  how to choose between two different datasets eg nlp and python
# Candidate # 302 :	  sagemaker vs python
# Candidate # 303 :	  ga tracking multiple times with gtm eg python
# Candidate # 304 :	  how to combine time embeddings
# Candidate # 305 :	  what is the difference between natural language processing and machine learning
# Candidate # 306 :	  tfidf for wikipedia articles
# Candidate # 307 :	  what are the best books on data science and machine learning
# Candidate # 308 :	  what is the best way to do data leakage in a scenario like this
# Candidate # 309 :	  keras pytorch for a convolutional neural network
# Candidate # 310 :	  what is the difference between data science and data analytics
# Candidate # 311 :	  what is the difference between sql and python
# Candidate # 312 :	  i am a python developer who wants to get into data science but have no idea where to start
# Candidate # 313 :	  what is the future of data science
# Candidate # 314 :	  how do i train a neural network with python in tensorflow
# Candidate # 315 :	  is it possible to get a job in ml with python from scratch
# Candidate # 316 :	  what are the best resources to learn data mining
# Candidate # 317 :	  what is the best way to learn deep learning for nlp
# Candidate # 318 :	  what is the best pc build for a ml laptop
# Candidate # 319 :	  i have a htaccess list of blocked referrals
# Candidate # 320 :	  what is the difference between python and jupyter notebooks
# Candidate # 321 :	  alpa for distributed dl on gpu clusters
# Candidate # 322 :	  what is the difference between a linear regression and python
# Candidate # 323 :	  what is the value of a data science phd
# Candidate # 324 :	  how do i train a ml model to predict time series data
# Candidate # 325 :	  predicting the time series with xgboost
# Candidate # 326 :	  pytorch keras and tensorflow
# Candidate # 327 :	  looking for a dataset that is based on demographics
# Candidate # 328 :	  what is the best way to learn deep learning
# Candidate # 329 :	  python msc data science vs udacity
# Candidate # 330 :	  what are the skills i should be learning before starting my ds career
# Candidate # 331 :	  what are some good skills for a data scientist
# Candidate # 332 :	  what are the advantages of using deep learning in the industry
# Candidate # 333 :	  how to add regularization term to a pytorch model
# Candidate # 334 :	  i am a ml developer and ive been working with python for years and have no idea where to start
# Candidate # 335 :	  how do i combine a cnn and an auc
# Candidate # 336 :	  what is the ideal use cases for a neural network
# Candidate # 337 :	  what statistical test should i use for this experiment
# Candidate # 338 :	  stanfordner python package for detecting first names
# Candidate # 339 :	  pytorch autoencoders for ml projects
# Candidate # 340 :	  what is the difference between data science and data analysis
# Candidate # 341 :	  what is a data cleaning process like in python
# Candidate # 342 :	  looking for a dataset with high employee satisfaction
# Candidate # 343 :	  which is the best tool for a data science career
# Candidate # 344 :	  what is the difference between a logarithm and python
# Candidate # 345 :	  i am a phd in stats and want to get into the data science world
# Candidate # 346 :	  what is the best way to prepare for a data science job description
# Candidate # 347 :	  what is the best way to track and analyze the content of a specific type of video
# Candidate # 348 :	  pytorch vs tensorflow keras
# Candidate # 349 :	  pytorch keras epochs
# Candidate # 350 :	  what is the best way to prepare for a ds internship
# Candidate # 351 :	  i am a ds intern who does not have any statistics experience but is it normal
# Candidate # 352 :	  what is the best way of storing a unique data set for nlp
# Candidate # 353 :	  how to break into the field of data science
# Candidate # 354 :	  nvidia vs pytorch for ml
# Candidate # 355 :	  what is the best way to get a job in data science
# Candidate # 356 :	  rahaf harvard a thinktank for social media amp the eroding effects of inequality
# Candidate # 357 :	  what is the difference between rbm and lstm in python
# Candidate # 358 :	  i am a ml student who is looking for feedback on coursera is data science course
# Candidate # 359 :	  what is the best way to track the content of a text field
# Candidate # 360 :	  resume critique for data scientist
# Candidate # 361 :	  what is the best value for a data science ml course
# Candidate # 362 :	  i am a mlds engineer who wants to get into data science but dont know how to do it
# Candidate # 363 :	  what is the future of data science
# Candidate # 364 :	  what is the best way to learn machine learning
# Candidate # 365 :	  what is the best way to store a large amount of data in python
# Candidate # 366 :	  cpu selection for anomaly detection
# Candidate # 367 :	  what is the most important part about data science
# Candidate # 368 :	  what is the difference between matlab and python
# Candidate # 369 :	  cnn for a pytorch game
# Candidate # 370 :	  python keras problem with deep q learning
# Candidate # 371 :	  i am a ml model that does not use jupyter notebooks or any other python libraries
# Candidate # 372 :	  i am a junior data scientist at ml and am looking for advice on how to approach it
# Candidate # 373 :	  what is the difference between mlnlp and data science
# Candidate # 374 :	  google analytics case study
# Candidate # 375 :	  what is the difference between a ds policy and an msc in data science
# Candidate # 376 :	  what is the best way to prepare for a ds interview
# Candidate # 377 :	  what is the best way to get into data science
# Candidate # 378 :	  what internships should i look for
# Candidate # 379 :	  what is the best way to store a lot of data in google analytics
# Candidate # 380 :	  how to use time series data in a python environment
# Candidate # 381 :	  laptop for aws
# Candidate # 382 :	  how do i approach this problem
# Candidate # 383 :	  how do i find a data science internship that is similar to google analytics
# Candidate # 384 :	  looking for a partner for my python data science project
# Candidate # 385 :	  how to merge duplicate names with python
# Candidate # 386 :	  what is the difference between data science and big data
# Candidate # 387 :	  ms in data science vs cs
# Candidate # 388 :	  how do i get the best results out of a regression problem
# Candidate # 389 :	  i am a finance student who wants to get into the data science field but have no idea where to start
# Candidate # 390 :	  how to measure the effectiveness of a meme
# Candidate # 391 :	  what is the difference between a ms in data science and analytics
# Candidate # 392 :	  what is the best way to store amp productize a bunch of real estate data
# Candidate # 393 :	  google analytics vs gtm in keras
# Candidate # 394 :	  how do i create a dashboard for my clients clients
# Candidate # 395 :	  r a python framework for deploying ml pipelines
# Candidate # 396 :	  gitutor is a python package that lets you use jupyter notebooks in production
# Candidate # 397 :	  what is the best way to improve my data science skills
# Candidate # 398 :	  what are the best models to use for time series forecasting
# Candidate # 399 :	  how would you go about estimating conversion rates for a lead
# Candidate # 400 :	  deep learning vs openvino
# Candidate # 401 :	  what is the best way to pay a lot of fees for this type of faqs
# Candidate # 402 :	  r a pytorch implementation of keras multiplication attention
# Candidate # 403 :	  what is the difference between data science and data analysis
# Candidate # 404 :	  what is the difference between data science and analytics
# Candidate # 405 :	  i am learning ds from scratch and am having some trouble finding a good way to do it
# Candidate # 406 :	  what is the best way to approach this problem
# Candidate # 407 :	  what is the best way to land a data science job in the us
# Candidate # 408 :	  what is the best way to organize your data science workflow
# Candidate # 409 :	  how to display a point cloud map in python
# Candidate # 410 :	  python tensorflow loss is too high
# Candidate # 411 :	  i am a junior data scientist at my current company and am looking for advice on my resume
# Candidate # 412 :	  how do you structure a presentation for data science
# Candidate # 413 :	  how do i go about estimating the impact of a new job
# Candidate # 414 :	  how do i decide if my pvalue is the same as the rest of the data
# Candidate # 415 :	  what is the best python tool for detecting a difference between two csv files
# Candidate # 416 :	  keras lstm output is too low
# Candidate # 417 :	  what is the best way to measure the impact of an event on a customer journey
# Candidate # 418 :	  what is the difference between data science and analytics
# Candidate # 419 :	  how do i save a lot of data in python
# Candidate # 420 :	  what certificates and training should i use for a data science phd
# Candidate # 421 :	  how to get a job in data analysis
# Candidate # 422 :	  best engineering blogs for data science
# Candidate # 423 :	  what is the best way to organize data for a data scientist
# Candidate # 424 :	  what are the skills you need for a data science phd
# Candidate # 425 :	  i am a business analyst intern and my coworkers are all pretty much the same as mine
# Candidate # 426 :	  looking for feedback on a data science project for nlp
# Candidate # 427 :	  i need your help figuring out which mldl game would be the best for me
# Candidate # 428 :	  predicting age for a csv file
# Candidate # 429 :	  i am a python student who wants to get into data science but have no experience in the field
# Candidate # 430 :	  what is the best way to store and update my image classification model
# Candidate # 431 :	  how hard is it to get a job in data science
# Candidate # 432 :	  what is the best way to prepare for the upcoming data science summit
# Candidate # 433 :	  looking for datasets with multiple variables
# Candidate # 434 :	  tensorflow on aws
# Candidate # 435 :	  tensorflow vs cudnn
# Candidate # 436 :	  msc in data science worth it if i already have a job as an analyst
# Candidate # 437 :	  what is the best way to store a large set of data
# Candidate # 438 :	  pytorch implementation of neural networks for detecting hidden inferences
# Candidate # 439 :	  i am a python student who wants to use ml for my project and want to save it to my local machine
# Candidate # 440 :	  calculating error of a convolutional neural network
# Candidate # 441 :	  what is the best way to play a game like this
# Candidate # 442 :	  how to get started with data science
# Candidate # 443 :	  what is the best way to learn spss and python for data analysis
# Candidate # 444 :	  what is the best way to track the location of a specific gps and compass data
# Candidate # 445 :	  how to extract a normalized image from an image
# Candidate # 446 :	  what is the best way to get a headstart in analytics
# Candidate # 447 :	  gisremote vs python for data science
# Candidate # 448 :	  what is the best way to prepare for my first job as a data scientist
# Candidate # 449 :	  i created a list of ml tools that you can use to improve your website ranking
# Candidate # 450 :	  what is the purpose of my ml project
# Candidate # 451 :	  what is the best way to get into data science as a data scientist
# Candidate # 452 :	  i have a lot of questions about ml in the google data studio
# Candidate # 453 :	  what is the difference between data science and software engineering
# Candidate # 454 :	  looking for feedback on delta academy is live competitive coding competition
# Candidate # 455 :	  what is the future of data science
# Candidate # 456 :	  what is your favorite part about data science
# Candidate # 457 :	  how do you organize your data
# Candidate # 458 :	  how to organize and organize a large dataset of lyrics
# Candidate # 459 :	  hora an blazingly fast python analytics
# Candidate # 460 :	  i am trying to track a specific page but it does not seem to be triggered by an event
# Candidate # 461 :	  msc statistics vs cs for data science
# Candidate # 462 :	  epochs in a convolutional neural network
# Candidate # 463 :	  ms in data science vs cs for a phd
# Candidate # 464 :	  what are your thoughts on the nyc data science project
# Candidate # 465 :	  how do i decode a neural network in python
# Candidate # 466 :	  what is the best way to display a large amount of social media data
# Candidate # 467 :	  what is the best way to approach this problem
# Candidate # 468 :	  what is the difference between a r and python
# Candidate # 469 :	  what are some of the best datasets for text classification
# Candidate # 470 :	  dqlib for data science
# Candidate # 471 :	  what is the difference between ds and msc data science
# Candidate # 472 :	  how to implement a recommendation system with keras
# Candidate # 473 :	  keras lstm outputs
# Candidate # 474 :	  what is the difference between a data science consultant and an analytics consultant
# Candidate # 475 :	  what is the best way to do crossvalidation on a cnn
# Candidate # 476 :	  is it possible to use a statistical model to detect patterns in traffic
# Candidate # 477 :	  what is the difference between deep learning and neural networks
# Candidate # 478 :	  covid data visualization for noncovid patients
# Candidate # 479 :	  how to get a data science job in europe
# Candidate # 480 :	  how to keep the passion alive in the ds space
# Candidate # 481 :	  what are the best features for a data synchronization study
# Candidate # 482 :	  econ major vs data science major
# Candidate # 483 :	  i am unable to load the tensorflow model even after rewriting it
# Candidate # 484 :	  dtw tensorflow keras dynamic time warping
# Candidate # 485 :	  ml engineer vs data scientist
# Candidate # 486 :	  how to create a funnel with jupyter notebooks
# Candidate # 487 :	  what is the future of ml
# Candidate # 488 :	  how to get an entrylevel data analyst job
# Candidate # 489 :	  what is the best way to get into data science
# Candidate # 490 :	  how to combine two different types of data into one dataset
# Candidate # 491 :	  looking for feedback on our data science program
# Candidate # 492 :	  what is the best way to store a lot of data in python and jupyter notebooks
# Candidate # 493 :	  what is the value proposition in data science
# Candidate # 494 :	  keras lstm model not training
# Candidate # 495 :	  what is the best way to store urls in google analytics
# Candidate # 496 :	  what is the value of data science
# Candidate # 497 :	  how do anchors get a different distribution in rpn
# Candidate # 498 :	  i am a pytorch developer who has been working with tensorflow for the past couple of years and have been experimenting with
# Candidate # 499 :	  i am a phd student who wants to get into ml
# Candidate # 500 :	  how do i make a decision tree from scratch
# Candidate # 501 :	  i am a senior data scientist at cs and want to help people who are looking to enter the field of data science
# Candidate # 502 :	  how to add pixel to a form in google analytics
# Candidate # 503 :	  what is the difference between a featurecentric model and the one that is not correlated to the rest of the data
# Candidate # 504 :	  what is the best way to get a job in data science
# Candidate # 505 :	  how do you manage a data science team
# Candidate # 506 :	  what are your thoughts on data governance
# Candidate # 507 :	  i am a data scientist but it does not know what to do with ml
# Candidate # 508 :	  what is the best way to learn the basics of ml
# Candidate # 509 :	  how do you approach a classification problem
# Candidate # 510 :	  how do i get better at data science
# Candidate # 511 :	  i am a ml engineer who wants to get into data science but dont know where to start
# Candidate # 512 :	  python for a db in smartsheets
# Candidate # 513 :	  what is the best way to use the kindle app for reading statistics on a laptop
# Candidate # 514 :	  how do i train a neural network to detect images that are very similar to yawn
# Candidate # 515 :	  what is the best way to automate this process
# Candidate # 516 :	  i got my first ds job as a new grad and it is still pretty much the same industry as the rest of the world
# Candidate # 517 :	  how to create art using ds tools
# Candidate # 518 :	  how to get into data science without a phd
# Candidate # 519 :	  how do i identify if a text is saturated or not
# Candidate # 520 :	  what is the best way to get a job in data science
# Candidate # 521 :	  looking for datasets with a lot of free parameters
# Candidate # 522 :	  what is the best way to get a job in data science
# Candidate # 523 :	  uidaho ms statistics vs north carolina phd
# Candidate # 524 :	  what is the best python library for a data scientist
# Candidate # 525 :	  pytorch laptop vs rtx ti for deep learning
# Candidate # 526 :	  what is the best way to simulate baseball games
# Candidate # 527 :	  what is the best way to learn python for deep learning
# Candidate # 528 :	  looking for a dataset of naive bayesian datasets
# Candidate # 529 :	  pca for feature reduction
# Candidate # 530 :	  tfidf for classification in python
# Candidate # 531 :	  i am a junior data scientist and ive been working with python for the last years and have no idea what to do next
# Candidate # 532 :	  what is the future of data science
# Candidate # 533 :	  what is the best way to do this
# Candidate # 534 :	  what is the best way to get started with a python script
# Candidate # 535 :	  is it worth getting a msc in data analytics
# Candidate # 536 :	  psych vs data science
# Candidate # 537 :	  how do you go about analyzing your data
# Candidate # 538 :	  how do i get started in data science
# Candidate # 539 :	  what is the best way to interpret this data
# Candidate # 540 :	  dvc version control for data science
# Candidate # 541 :	  how do i get my foot in the door as a data scientist
# Candidate # 542 :	  a question about time series prediction
# Candidate # 543 :	  what is the best way to organize text data for nlp
# Candidate # 544 :	  how to find remote jobs in the us
# Candidate # 545 :	  microsoft vs googleai for ml research
# Candidate # 546 :	  what is the difference between sys analyst and devops
# Candidate # 547 :	  scala vs python for data science
# Candidate # 548 :	  how do i become a data scientist
# Candidate # 549 :	  what is the best way to train a cnn to detect motion objects
# Candidate # 550 :	  how to fix subscription churned prediction
# Candidate # 551 :	  looking for a data scientist with nlp background
# Candidate # 552 :	  how to get into the data science world
# Candidate # 553 :	  what is your favorite part about data science
# Candidate # 554 :	  how do i train a model error when the loss is too high
# Candidate # 555 :	  how much should i charge for cloud plateform training
# Candidate # 556 :	  what is the best way to track a link in an analytics website
# Candidate # 557 :	  how to create a training dataset for nlp
# Candidate # 558 :	  what is the difference between data science and machine learning
# Candidate # 559 :	  is it worth getting a msc in data science
# Candidate # 560 :	  what is the best way to get into the data science field
# Candidate # 561 :	  pytorch keras input and output dimensions are the same
# Candidate # 562 :	  what is the best way to learn ml
# Candidate # 563 :	  how much cs is involved in data science
# Candidate # 564 :	  what is the best way to learn ml for a medical student
# Candidate # 565 :	  predicting the number of points in a nba game
# Candidate # 566 :	  looking for a complete us dollar data set
# Candidate # 567 :	  what are the skills you need for ml engineering
# Candidate # 568 :	  how do you go about creating a data visualization tool
# Candidate # 569 :	  how do you do segmentation for a specific city
# Candidate # 570 :	  data science jobs in denver or austin tx
# Candidate # 571 :	  what are the core skillsets of data science
# Candidate # 572 :	  i am looking for a data set for my company that does not use jupyter notebooks
# Candidate # 573 :	  federated averaging
# Candidate # 574 :	  i am a jupyter notebook developer who is looking for feedback on my python notebooks
# Candidate # 575 :	  what is the best approach for detecting anomalies in a dataset
# Candidate # 576 :	  what is the best way to track and analyze a bunch of misinformation on the internet
# Candidate # 577 :	  how do i choose the best weights for my python classifier
# Candidate # 578 :	  how do you approach a data science interview
# Candidate # 579 :	  what is the best way to visualize the impact of a specific metric on sales
# Candidate # 580 :	  what is the best way to do nlp for a specific type of text
# Candidate # 581 :	  phd in data science vs ms in analytics
# Candidate # 582 :	  what is the difference between a data scientist and an ml engineer
# Candidate # 583 :	  how would you approach this problem
# Candidate # 584 :	  python vs jupyter notebooks
# Candidate # 585 :	  what is the difference between a data scientist and an entry level position in the healthcare industry
# Candidate # 586 :	  how to get into data science with a bsc in ds
# Candidate # 587 :	  how do i make a line graph with python
# Candidate # 588 :	  i have a bsc in ds and am looking to get into this field
# Candidate # 589 :	  what is the best way to optimize a fully connected cnn
# Candidate # 590 :	  how to add a value to the decision tree in cnn
# Candidate # 591 :	  how to set custom parameters in python
# Candidate # 592 :	  what is the best way to parse time series data
# Candidate # 593 :	  what is the best way to learn data science
# Candidate # 594 :	  how do i set up a validation set for my neural network
# Candidate # 595 :	  why is the neural ode technique still used in a pytorch implementation
# Candidate # 596 :	  what is the best way to get into data science
# Candidate # 597 :	  looking for a dataset of images of different types of cells
# Candidate # 598 :	  what is the best way to evaluate a ds model
# Candidate # 599 :	  how do you organize your data
# Candidate # 600 :	  how do i package my csv into a python script
# Candidate # 601 :	  what is the best gpu for a beginner in deep learning
# Candidate # 602 :	  what are some basic questions i should be doing to become a data scientist
# Candidate # 603 :	  what is the best way to get a job in the russian military
# Candidate # 604 :	  how to bridge the gap between technical skills and data science
# Candidate # 605 :	  what is the best way to get into data science
# Candidate # 606 :	  what is the best way to train a wgan on the same dataset
# Candidate # 607 :	  how to add rows to a csv
# Candidate # 608 :	  what are the key drivers of data science
# Candidate # 609 :	  i am a physics phd student who wants to get into data science
# Candidate # 610 :	  free nlp course for beginners
# Candidate # 611 :	  how would you go about balancing a gyroscope with an lstm
# Candidate # 612 :	  what is the best way to get into data science as a software engineer
# Candidate # 613 :	  keras generator does not change the output of the latent image
# Candidate # 614 :	  i am a cs student who lives outside of the us what are some ways to get into the data science world
# Candidate # 615 :	  i am a beginner in the field of ml and would like your inputs to be able to do it
# Candidate # 616 :	  what is the difference between data science and data analytics
# Candidate # 617 :	  what is the best way to prepare for a data science interview
# Candidate # 618 :	  what are your thoughts on the data science side of data analytics
# Candidate # 619 :	  what is the best way to recover text from a txt using javascript
# Candidate # 620 :	  what is the right way to get a job in data science
# Candidate # 621 :	  i am a senior data scientist at my company and ive been tasked with figuring out how to improve my ml skills
# Candidate # 622 :	  i am a msc in statistics and want to get into the data science field but am not sure where to start
# Candidate # 623 :	  what is the future of data science
# Candidate # 624 :	  how do you deal with a huge spike in confidence in your organization
# Candidate # 625 :	  how do i match the output of a machine learning algorithm
# Candidate # 626 :	  tensorflow lstm is not normalized
# Candidate # 627 :	  free gpu servers for deep learning
# Candidate # 628 :	  what is the best way to get a job in data science
# Candidate # 629 :	  how do you approach this problem i am working on
# Candidate # 630 :	  what is the best way to get a job in data science
# Candidate # 631 :	  i am a cs student who wants to get into data science
# Candidate # 632 :	  what is the best way to learn data science
# Candidate # 633 :	  advice for a data science grad
# Candidate # 634 :	  what is the best way to put data into a python neural network
# Candidate # 635 :	  what is the difference between data science and machine learning
# Candidate # 636 :	  what is the best way to organize and organize data
# Candidate # 637 :	  how do i get my dataset to work in a way that is completely unbalanced
# Candidate # 638 :	  how to create a portfolio for edx
# Candidate # 639 :	  combining multiple predictors into one time series
# Candidate # 640 :	  python parse vs keras
# Candidate # 641 :	  analyzing latlong coords and d physical store location
# Candidate # 642 :	  is it possible to get a data science job if i do not have any experience
# Candidate # 643 :	  what is the best way to visualize a data set
# Candidate # 644 :	  combining wss and cnn for classification
# Candidate # 645 :	  dvt a python tool for data validation
# Candidate # 646 :	  how do i train a neural network with pytorch and tensorflow
# Candidate # 647 :	  looking for datasets of crime scene images
# Candidate # 648 :	  how to cluster a large set of features
# Candidate # 649 :	  what to do next year if i do not have a phd
# Candidate # 650 :	  i am trying to find a dataset of reviews and reviews that are not saturated
# Candidate # 651 :	  what is the best way to store a large amount of uncompressed data
# Candidate # 652 :	  i am a bsc in data science and want to get into the field
# Candidate # 653 :	  ms in data science or not
# Candidate # 654 :	  question about free parameters in physics
# Candidate # 655 :	  what is the best way to train a rnn for mldl
# Candidate # 656 :	  what is the best way to get into data science
# Candidate # 657 :	  arima model for forecasting
# Candidate # 658 :	  how do i measure the effectiveness of a specific set of data
# Candidate # 659 :	  i am a mathematician but hes not able to explain the reasoning behind it all
# Candidate # 660 :	  predicting event based on the probability of an event
# Candidate # 661 :	  gtm vs keras
# Candidate # 662 :	  what are some of your favorite data science projects
# Candidate # 663 :	  how to use twitter for learning purposes
# Candidate # 664 :	  tensorflow pytorch keras
# Candidate # 665 :	  ms in data science vs uc berkeley
# Candidate # 666 :	  what is the best way to structure a neural network for this problem
# Candidate # 667 :	  how to become a data scientist
# Candidate # 668 :	  why is the cost function used in a python model
# Candidate # 669 :	  what are the next steps for a data scientist
# Candidate # 670 :	  what is the best way to cluster a dataset
# ...
# Candidate # 1035 :	  looking for a data set that is not sex but is based on the us census
# Candidate # 1036 :	  i am a ml developer who is looking for datasets that are not saturated
# Candidate # 1037 :	  what are the advantages of supervised learning for a beginner
# Candidate # 1038 :	  i am a ml engineer and if you are using lstms what are the drawbacks of the naive bayes algorithm
# Candidate # 1039 :	  arima multivariate time series model
# Candidate # 1040 :	  what is the best way to embed a pythonbased dsml tool in an application
# Candidate # 1041 :	  i am a beginner who wants to learn mlds and python but dont know how to do it
# Candidate # 1042 :	  what is the best way to do a regression analysis
# Candidate # 1043 :	  what is the difference between f score and ml
# Candidate # 1044 :	  how do i save a bunch of images using tab save for ddos attack
# Candidate # 1045 :	  question about tableau native connectors
# Candidate # 1046 :	  i am a python developer who is experimenting with ml and ds how do you do it
# Candidate # 1047 :	  syracuse vs uc berkeley for ms in data science
# Candidate # 1048 :	  what is the right way to get a job in data science
# Candidate # 1049 :	  how do you go about creating a report that is based on the data i have been working on
# Candidate # 1050 :	  what is the best way to find a good data analysis book
# Candidate # 1051 :	  what is the best way to prepare for a career in data science
# Candidate # 1052 :	  how are autoencoders used in feature reduction
# Candidate # 1053 :	  i am a cs student who wants to use python and nlp but have no idea on how to do it
# Candidate # 1054 :	  why is the loss function so low
# Candidate # 1055 :	  what is the best way to get into data science
# Candidate # 1056 :	  adobe illustrator vs python
# Candidate # 1057 :	  adobe vs python
# Candidate # 1058 :	  what is the best way to load a sql database in python
# Candidate # 1059 :	  how do i set up adwords conversion number in google analytics
# Candidate # 1060 :	  what is the difference between a keras and pytorch vs tensorflow
# Candidate # 1061 :	  how do you go about creating a report that is based off of of google analytics
# Candidate # 1062 :	  phd in biotech looking for a ds position in cambridge
# Candidate # 1063 :	  what is the best way to get a job in data science
# Candidate # 1064 :	  what are some good ml projects that i can do to increase my chances of landing a data science internship
# Candidate # 1065 :	  a list of pumas in the usa
# Candidate # 1066 :	  data science vs power bi
# Candidate # 1067 :	  how do i visualize a mean rsquared in python
# Candidate # 1068 :	  kaggle competitions
# Candidate # 1069 :	  is it possible to get a data science job in austria
# Candidate # 1070 :	  what is the best way to prepare for a data science job
# Candidate # 1071 :	  what is the best way to learn python and sql
# Candidate # 1072 :	  how to save a json shape in pytorchtensorflow
# Candidate # 1073 :	  pytorch vs tensorflow
# Candidate # 1074 :	  what are the best resources for learning machine learning
# Candidate # 1075 :	  how to prepare for a data science presentation
# Candidate # 1076 :	  what is the best way to get into a data science job
# Candidate # 1077 :	  how to get a job in data science
# Candidate # 1078 :	  what is the best way to model a product
# Candidate # 1079 :	  what are the skills i should have in a ds team
# Candidate # 1080 :	  python how do i keep my data in a format that is not sexy
# Candidate # 1081 :	  i am trying to build a python script for my site but it does not seem to work
# Candidate # 1082 :	  how do i create a convolutional neural network with tensorflow in keras
# Candidate # 1083 :	  what is the best way to visualize data science concepts
# Candidate # 1084 :	  what is the best way to set up a pytorch environment for data science
# Candidate # 1085 :	  i am a new data analyst and ive been told to use sql for my current job but if you have access to it what is the
# Candidate # 1086 :	  what is the best way to get into data science as a cs major
# Candidate # 1087 :	  x nerf for gans
# Candidate # 1088 :	  a question about likelihood functions
# Candidate # 1089 :	  l regularization for feature selection
# Candidate # 1090 :	  i am a ds who does not use jupyter notebooks
# Candidate # 1091 :	  what is the best way to do a pytorch model overfitting
# Candidate # 1092 :	  what is the reason i am getting a lot of errors in my first ds assignment
# Candidate # 1093 :	  what is the best way to get a job in data science
# Candidate # 1094 :	  is it worth getting a phd in data science
# Candidate # 1095 :	  unet model for synthetic images with spectral normalization
# Candidate # 1096 :	  how much data science is needed for a ml project
# Candidate # 1097 :	  tensorflow keras lstm output error
# Candidate # 1098 :	  i am a cs major and ive been looking for ms in data science
# Candidate # 1099 :	  i am a web analytics consultant and ive been tasked with some data analysis but am not sure how to do it
# Candidate # 1100 :	  what is the difference between data science and data engineering
# Candidate # 1101 :	  what is the best approach for a timeseries model
# Candidate # 1102 :	  what is the future of data science
# Candidate # 1103 :	  what is the best way to get a job in data science
# Candidate # 1104 :	  how to store a lot of data while storing the data
# Candidate # 1105 :	  i am a new data science project from scratch and am looking for feedbacks on my project
# Candidate # 1106 :	  what are your thoughts on data science and analytics
# Candidate # 1107 :	  what is the best way to get a job in data science
# Candidate # 1108 :	  mckinsey vs ds
# Candidate # 1109 :	  how to add features to a timeseries model
# Candidate # 1110 :	  how to approach this problem in keras
# Candidate # 1111 :	  i am a math teacher who wants to get into the data science field but dont know where to start
# Candidate # 1112 :	  how to start freelancing on upwork
# Candidate # 1113 :	  how do you approach a take home data science problem
# Candidate # 1114 :	  ms in data science vs python
# Candidate # 1115 :	  i am a web developer who wants to make the world of data science
# Candidate # 1116 :	  what is the best way to preform a ml model in python
# Candidate # 1117 :	  what is the best way to track the quality of a specific type of gear
# Candidate # 1118 :	  kaggle dataset
# Candidate # 1119 :	  how to visualize splunks in python
# Candidate # 1120 :	  what is the best way to measure the loss function in a neural network
# Candidate # 1121 :	  what is the difference between a call center and an average time series
# Candidate # 1122 :	  q deconvolutional neural network in pytorch
# Candidate # 1123 :	  i am a phd student who wants to get into data science
# Candidate # 1124 :	  ms in data science vs phd in analytics
# Candidate # 1125 :	  is the use of rrregression a good fit for ds
# Candidate # 1126 :	  what is the best way to store a lot of tweets in mysql
# Candidate # 1127 :	  what is the best way to store data for a business analyst
# Candidate # 1128 :	  looking for data sets for dutch disease
# Candidate # 1129 :	  i am a business analyst who wants to get into the data science world
# Candidate # 1130 :	  how to train a cnn to detect objects
# Candidate # 1131 :	  ms in data science
# Candidate # 1132 :	  what are the skills you need for a data scientist
# Candidate # 1133 :	  how do i approach this problem
# Candidate # 1134 :	  how do i become a data scientist
# Candidate # 1135 :	  google analytics vs facebook pixel tag manager for ad hoc analysis
# Candidate # 1136 :	  aws vs jetsql for python and tensorflow
# Candidate # 1137 :	  how to group news with a very limited dataset
# Candidate # 1138 :	  tensorflow lstm for multiheadattention in pytorch
# Candidate # 1139 :	  what is the correct way of calculating a score for the competition
# Candidate # 1140 :	  aws or python for data analytics internship
# Candidate # 1141 :	  what is the difference between attribution and direct traffic
# Candidate # 1142 :	  keras k images in tensorflow backend
# Candidate # 1143 :	  how to get a job in data science
# Candidate # 1144 :	  how to improve my resume
# Candidate # 1145 :	  looking for a tool to search for simple and ambiguous data in tensorflow
# Candidate # 1146 :	  what is the value of a data science certificate
# Candidate # 1147 :	  how to choose the length of lstm
# Candidate # 1148 :	  what is the best way to build a neural network for this project
# Candidate # 1149 :	  i am a mathematician who is very good at math calculus
# Candidate # 1150 :	  i have a data science internship interview tomorrow and it is not for me any advice would be appreciated
# Candidate # 1151 :	  which industry is better for data science vs finance
# Candidate # 1152 :	  tensorflow keras pytorch implementation
# Candidate # 1153 :	  ssn in kerastensorflow
# Candidate # 1154 :	  what are the best practices for storing data in a way that is not saturated
# Candidate # 1155 :	  what is the entropy of the decision tree
# Candidate # 1156 :	  python vs gpus for a data science laptop
# Candidate # 1157 :	  python keras lt i am trying to get the html code to work in jupyter notebooks
# Candidate # 1158 :	  i am a gis grad student who is looking for advice on navigating the data science job market
# Candidate # 1159 :	  what is the best way to collect data for a lstm
# Candidate # 1160 :	  ms in data science vs cs for ds
# Candidate # 1161 :	  how do you approach this problem
# Candidate # 1162 :	  how do you organize your worklife balance
# Candidate # 1163 :	  how do you go about creating a unique event report
# Candidate # 1164 :	  converting a numpy image into tensorflow
# Candidate # 1165 :	  what is the best way of storing a bunch of images in tensorflow keras
# Candidate # 1166 :	  what is the best way to get a job in data science
# Candidate # 1167 :	  ms in statistics vs phd in data science
# Candidate # 1168 :	  how to get a job in analytics
# Candidate # 1169 :	  how do i get the best results out of a cnn
# Candidate # 1170 :	  looking for a dataset of census tracts andoror counties
# Candidate # 1171 :	  ms in data science vs uc berkeley
# Candidate # 1172 :	  i am a python student who wants to make rd year of data science and want to do it
# Candidate # 1173 :	  what is the best way to prepare for a ml class
# Candidate # 1174 :	  ssl vs unsupervised domain adaptation
# Candidate # 1175 :	  pytorch vs tensorflow
# Candidate # 1176 :	  what is the best way to get into data science
# Candidate # 1177 :	  what is the difference between a msc in statistics and data science
# Candidate # 1178 :	  sanity check with json and keras
# Candidate # 1179 :	  how do i get a job as an entry level data scientist
# Candidate # 1180 :	  i am looking for a dataset of handwritings that are not sex but are based on python
# Candidate # 1181 :	  what is the best way to approach this problem
# Candidate # 1182 :	  mlai vs python for vape
# Candidate # 1183 :	  r a pytorch implementation of deepmind for computer vision
# Candidate # 1184 :	  how do you go about creating a python pipeline for your business
# Candidate # 1185 :	  looking for nfl datasets
# Candidate # 1186 :	  what is a good way to improve the accuracy of glm
# Candidate # 1187 :	  how to improve the ml testing for a company
# Candidate # 1188 :	  keras lstm outputs are very similar to the ones in python
# Candidate # 1189 :	  what is the best way of predicting a single variable in aggregated data
# Candidate # 1190 :	  what is the next step in my career
# Candidate # 1191 :	  what is the best way to prepare for an nfl internship
# Candidate # 1192 :	  spacy ner question
# Candidate # 1193 :	  how do you deal with a lot of data when you are not really good at it
# Candidate # 1194 :	  what is the best way to display a user is behavior in google analytics
# Candidate # 1195 :	  what is the best way to do a pytorchbased facial recognition project
# Candidate # 1196 :	  i am a software engineer who wants to be mlds but if you want to do it what is the best way to implement it
# Candidate # 1197 :	  rnn for predicting numeric sequences
# Candidate # 1198 :	  what is the best way to store a large amount of data in tensorflow
# Candidate # 1199 :	  what is the difference between a deep learning course and the course is it worth it
# Candidate # 1200 :	  calculating time of arrival for a truck
# Candidate # 1201 :	  what is the difference between a causal inference and analytics in python
# Candidate # 1202 :	  what is the difference between a ms in ds and cs
# Candidate # 1203 :	  what is the difference between a python and numpy
# Candidate # 1204 :	  what is the best way to do a python data science project
# Candidate # 1205 :	  what is the difference between a fully remote ds team and an msc in data science
# Candidate # 1206 :	  what is the best way to train a neural network in tensorflow
# Candidate # 1207 :	  how to get a data scienceanalytics job
# Candidate # 1208 :	  deciding between two data science vs a bsc in applied statistics
# Candidate # 1209 :	  looking for a framework to improve the accuracy of words in backend
# Candidate # 1210 :	  how does intellectual property work for a company
# Candidate # 1211 :	  keras tensorflow pytorch not training
# Candidate # 1212 :	  what are the best data science bootcamps
# Candidate # 1213 :	  finetuning a multilingual model
# Candidate # 1214 :	  what is the future of machine learning
# Candidate # 1215 :	  how do you go about building a model that predicts the number of variables that you can add in to your cvs
# Candidate # 1216 :	  r a pytorch implementation of nlstm for graph classification
# Candidate # 1217 :	  what is the difference between data science and business analytics
# Candidate # 1218 :	  i am a ml developer who does not use jupyter notebooks
# Candidate # 1219 :	  what is the proper way of calculating confidence intervals in a python script
# Candidate # 1220 :	  what is the difference between data science and software development
# Candidate # 1221 :	  what is the future of data science
# Candidate # 1222 :	  how do you keep tabs on your data
# Candidate # 1223 :	  what is the best way to train a neural network in tensorflow
# Candidate # 1224 :	  i am a senior data scientist at my company and ive been tasked with ds for the past few months
# Candidate # 1225 :	  what is the best way to learn data science
# Candidate # 1226 :	  gpt client v features in pytorch
# Candidate # 1227 :	  telegram speakerchatter
# Candidate # 1228 :	  what is the best way to add feature importance to a neural network
# Candidate # 1229 :	  i created an android app to track and add images to your csv file
# Candidate # 1230 :	  google analytics drop offs
# Candidate # 1231 :	  overfitting in kerastensorflow
# Candidate # 1232 :	  adobe analytics vs python
# Candidate # 1233 :	  python rnn for social media analytics
# Candidate # 1234 :	  is it possible to get a ms in data science with python
# Candidate # 1235 :	  i am a software developer who wants to do ml in months
# Candidate # 1236 :	  i have a bsc in physics and ms in data science and want to get into ds
# Candidate # 1237 :	  what is the best combination of ai and deep learning
# Candidate # 1238 :	  how do i track multiple domains with a single url
# Candidate # 1239 :	  what is the difference between a sigmoid and an nn
# Candidate # 1240 :	  m conference on data science and machine learning at the university of nicosia and nyu
# Candidate # 1241 :	  what are some of the best data science projects you have seen
# Candidate # 1242 :	  what is the difference between a msc in data science and computer science
# Candidate # 1243 :	  what is the difference between data science vs tech
# Candidate # 1244 :	  i am a cs student who wants to get into the data science field but dont know where to start
# Candidate # 1245 :	  i am a cv developer who does not use jupyter notebooks
# Candidate # 1246 :	  looking for a dataset of self identifiers
# Candidate # 1247 :	  what are your favorite papers on lstm for speech recognition
# Candidate # 1248 :	  what is the best way to preprocess data in tensorflow
# Candidate # 1249 :	  deepsvg for vector graphics generation

# %%
# References: we will compare the generated titles against these actual test values
start_time = time.time()

# reference list
references = [item['title'] for item in test_pairs[:EXAMPLES_NUM]]

# original post
references_post = [item['post'] for item in test_pairs[:EXAMPLES_NUM]]

# Inspect references list
for idx, reference in enumerate(references):
    print("Reference #",idx,":\t ",reference)

end_time = time.time()
run_time = end_time - start_time
print(f"Generate Time elapsed: {run_time} seconds.\n")
# Out:
# Reference # 0 :	  i want to transition into the data scienceanalyst or related field rather than asking whether i should choose a particular boootcamp or learn some language i would like to hear opinions on what path should i choose that will land me a job of some kind in the field as soon as possible
# Reference # 1 :	  psngram linguistic features for improving machine learning and deep learning model accuracy for the first time in python new release
# Reference # 2 :	  does anyone use any type of gradient smoothing for binned data
# Reference # 3 :	  setting up a model for retraining in production
# Reference # 4 :	  is mahalanobisdistance matching between points not compatible with onehotencoded datasets
# Reference # 5 :	  education level on applications
# Reference # 6 :	  how many yoe should i expect to have before i hit kk salary range
# Reference # 7 :	  a potential blind spot for new data science degrees
# Reference # 8 :	  should i get a mastersphd
# Reference # 9 :	  two years until i apply for jobs what should i work on
# Reference # 10 :	  why python is used in data science how data science courses help in a successful career post covid pandemic
# Reference # 11 :	  how to transition from data analyst to a data science role
# Reference # 12 :	  knight commission unveils new college sports financial database
# Reference # 13 :	  how to learn more about amazon is automation
# Reference # 14 :	  confusion regarding bioinformatics and health informatics
# Reference # 15 :	  is it hard to become an entry level data analyst
# Reference # 16 :	  what is my wrong with my resume
# Reference # 17 :	  data scientist looking for a change
# Reference # 18 :	  looking for insight on data analysis on these job description
# Reference # 19 :	  masters course selection
# Reference # 20 :	  recent grad who had his offer revoked and interview cancelled
# Reference # 21 :	  what capabilities does your team have
# Reference # 22 :	  transitioning to ds from financeinvestment background
# Reference # 23 :	  overcome caveats on using deep learning for faster inference on limited performance availability
# Reference # 24 :	  increase similarity between two vectors whilst maintaining similarity to other vectors
# Reference # 25 :	  marketing mix model help
# Reference # 26 :	  project help
# Reference # 27 :	  data enthusiasts paid interview graduate research project
# Reference # 28 :	  i need help representing data about d changes in vector orientation
# Reference # 29 :	  why cannot i view any data in the behavior flow
# Reference # 30 :	  interviews what do they want to know about my past projects
# Reference # 31 :	  confused and lost at where to start
# Reference # 32 :	  bs in economics or bs in computer science
# Reference # 33 :	  why am i getting error while performing fit transform
# Reference # 34 :	  a few questions on modelling time series data with recurrent neural networks
# Reference # 35 :	  how can i have an organized workflow in r
# Reference # 36 :	  moocs for university student
# Reference # 37 :	  can a learning rate graph look unusual and weird
# Reference # 38 :	  how do you manage multiple experiments in ml
# Reference # 39 :	  pages i am not hosting are showing in google analytics
# Reference # 40 :	  advice on switching career to development sector
# Reference # 41 :	  affordable supercomputers for ai data science amp design
# Reference # 42 :	  a python developer with too much free time needs your input
# Reference # 43 :	  would having a mathematically described function that approximates the function encoded in a neural network help researchers understand how a neural network gets its output
# Reference # 44 :	  what is a data catalog and why should you even care
# Reference # 45 :	  how to get google colab environmentimage to gcp
# Reference # 46 :	  host and serve your scikitlearn tensorflow and pytorch models within minutes
# Reference # 47 :	  in layperson is terms how much does deep learning performance scale with training examples
# Reference # 48 :	  business process change implementation
# Reference # 49 :	  what exactly is senior analyst data scientist role i am confused with responsibilities and corresponding tc
# Reference # 50 :	  dealing with when observations have a variable list of traits
# Reference # 51 :	  creating a data set from scratch having trouble
# Reference # 52 :	  advice for a beginner
# Reference # 53 :	  article the swish activation function
# Reference # 54 :	  creating a customer attrition model for my work
# Reference # 55 :	  p automatic reddit categorizer update first version working
# Reference # 56 :	  is data structures and algorithms worth spending my time on before i start my job
# Reference # 57 :	  social media management platform with reporting api
# Reference # 58 :	  how do kernels in svms give rise to decision boundaries
# Reference # 59 :	  looking for post undergrad advice
# Reference # 60 :	  what kind of industry job can i get with interest in text analysis
# Reference # 61 :	  day recommender systems
# Reference # 62 :	  best models for managing inventory supplydemand
# Reference # 63 :	  curriculum to get started
# Reference # 64 :	  what is your routine like as a data analyst
# Reference # 65 :	  get data for all firstlevel administrative divisions for all countries
# Reference # 66 :	  logistic regression for predicting goodbad customers scoring model development
# Reference # 67 :	  tapping this sub for some resources i am looking to a tap into some api feeds b do stuff with the resulting data graph manipulate etc c deliver it in the form of a data product web mobile etc
# Reference # 68 :	  question about feature importanceselection
# Reference # 69 :	  random translation output with pretrained opennmtpy model
# Reference # 70 :	  how do i combine several time series into one given a dataset of how the end result should be
# Reference # 71 :	  do not allow your isp and government to save your browsing history
# Reference # 72 :	  linear regression on tensorflow all nans
# Reference # 73 :	  retraining cnn with new data
# Reference # 74 :	  question about learning sql after learning data analysisbased python pandas library
# Reference # 75 :	  economist that just started a msc in econ specializing in data science and numerical methods should i just drop it and focus on selflearning everything
# Reference # 76 :	  do you think generated datasets when realworld ones are scarce can help training and if so who could find them useful
# Reference # 77 :	  spacy word vectors and sklearn
# Reference # 78 :	  lead scoring model for marketing
# Reference # 79 :	  is it okay to email hiring manager if the recruiter is not responding
# Reference # 80 :	  google data studio create language button
# Reference # 81 :	  newbie why so little machine learning model package in r
# Reference # 82 :	  need help postprocessing image segmentation masks
# Reference # 83 :	  wavenet output dimensions
# Reference # 84 :	  has anyone here made a career change into data science what was your experience like
# Reference # 85 :	  need data science project supervisionresources
# Reference # 86 :	  difference between model and algorithm
# Reference # 87 :	  eve ai
# Reference # 88 :	  entering data science with economicseconometricsfinance background
# Reference # 89 :	  gadget accessories recommender system need some ideas amp questions to answer
# Reference # 90 :	  is detailed knowledge of math behind machine learning essential
# Reference # 91 :	  product survey gift card
# Reference # 92 :	  looking into switching to cis major but i am afraid i have too little computer knowledge
# Reference # 93 :	  visualizing the activations within an rnn
# Reference # 94 :	  need some help with google optimize
# Reference # 95 :	  no idea where custom built neural network is going wrong
# Reference # 96 :	  discussion communicating technical results
# Reference # 97 :	  need help using multivariate time series or other supervised methods to predict a continuous future outcome with two date attributes
# Reference # 98 :	  suggested selfstudy plan for data science for those acquainted with the basics
# Reference # 99 :	  how to build an incremental learning model
# Reference # 100 :	  good sources to learn differences between various data storage options
# Reference # 101 :	  tell me how to learn machine learning in months
# Reference # 102 :	  which university degree would you recommend
# Reference # 103 :	  learn machine learning reading answers like stack overflow
# Reference # 104 :	  best way to start learning how to actually package analyses into products
# Reference # 105 :	  ds job market in ca after graduating from uoft mscac
# Reference # 106 :	  softwareplatforms for monitoring data and models
# Reference # 107 :	  university business analytics help
# Reference # 108 :	  if your job reimbursed education expenses what would you do
# Reference # 109 :	  is there a presentationlike tool that allows the use of plotly is interactive plots
# Reference # 110 :	  suggestions on insights to look into regarding sales data
# Reference # 111 :	  linear regression kfold and gridsearch
# Reference # 112 :	  question how to deal with regression with high auto correlation
# Reference # 113 :	  data analysis sanity check
# Reference # 114 :	  man data science and ml sure is broad
# Reference # 115 :	  cs or applied stats minor
# Reference # 116 :	  p integrate your ml model with your favorite apps from a single python file
# Reference # 117 :	  p making a model for nauto hand sign detection
# Reference # 118 :	  gtm implementation
# Reference # 119 :	  google did not help solve my doubts regarding a modelling problem can you
# Reference # 120 :	  algorithms for combining models in image recognition object detection computer vision machine vision
# Reference # 121 :	  looking for a ml study partner to help with my motivation
# Reference # 122 :	  book i found very helpful in understanding the basics of neural networks
# Reference # 123 :	  hiring managers for data analyst interns are you looking for anything specific
# Reference # 124 :	  will computer science major people start becoming more desirable as the interview process moves more towards leetcode style
# Reference # 125 :	  classification rescaling or standardisation
# Reference # 126 :	  can someone help me with this problem statement
# Reference # 127 :	  choosing between intro to optimization and computation statistics course
# Reference # 128 :	  udacity nanodegrees or certifications even worth it
# Reference # 129 :	  future of data science
# Reference # 130 :	  i would like help understanding the maths behind back propagation
# Reference # 131 :	  help with exploratory data analysis
# Reference # 132 :	  network anomalie detection on wifi router
# Reference # 133 :	  count people in video stream using object detection yoloopencv
# Reference # 134 :	  trying to read sebastian raschka is python machine learning completely lost on the very first code is visual representation with matplotlib
# Reference # 135 :	  what do you when people keeps asking to add more data to your model
# Reference # 136 :	  looking for analytics tools for share point
# Reference # 137 :	  advice for someone who wants to start working on machine learning related jobs
# Reference # 138 :	  entry level business analyst confused about what decision to make
# Reference # 139 :	  datascience projects collab
# Reference # 140 :	  can i track data from ebay listings with google tag manager google analytics
# Reference # 141 :	  neuroevolution on boxlabelled dataset
# Reference # 142 :	  lead data scientist compensation question
# Reference # 143 :	  aspiring data scientist postundergrad career advice needed
# Reference # 144 :	  how to dettect rectangles in a simple image pytorch
# Reference # 145 :	  deciding a classification algorithm
# Reference # 146 :	  data science on a budget
# Reference # 147 :	  is this feasible to apply ml to
# Reference # 148 :	  thought i nailed presentation on pipeline i built business ppl were like where are the results ugh
# Reference # 149 :	  multiple gpu performance w keras andor tensorflow
# Reference # 150 :	  how to use cuda pinned zerocopy memory for a memory mapped file
# Reference # 151 :	  road to become a data analyst
# Reference # 152 :	  how the heck does the backpropagation works in neural network
# Reference # 153 :	  am i employable in ds or ml with my background
# Reference # 154 :	  which model to apply on such panel data where for each id have only records total records d
# Reference # 155 :	  looking for someone who has done the first derivatives data science graduate program or is familiar with their kx suite to talk about their experience and experiences after
# Reference # 156 :	  ok i know bootcamps are not a magical golden key and that there are mixed opinions of their graduates from employers but hear me out and let me know what you think do i have a shot at this
# Reference # 157 :	  tradingbot my team is looking for datascientist amp who can help to create db we are starting with vol of our bot all team members share the source code as reward
# Reference # 158 :	  can anyone break the vague term wouldata science into different branches or areas for me please
# Reference # 159 :	  home appliances general review aspects data
# Reference # 160 :	  what are the long term career prospects in this field
# Reference # 161 :	  oh no not another datacamp noob question
# Reference # 162 :	  your ideas how to forecast prices find good trades in game economy
# Reference # 163 :	  i understand wordvec but i fail to grasp docvec
# Reference # 164 :	  when having ethical concerns do degrees of separation matter
# Reference # 165 :	  i just got a job as the first ever data scientist in a startup company i only have about months of prior experience in the field from an internship how can i do a good job
# Reference # 166 :	  sql green thumb trying to make temp table
# Reference # 167 :	  offered a job titled graph knowledge scientist dont understand what it is
# Reference # 168 :	  help need advice regarding research topic robot learning
# Reference # 169 :	  why use logarithm
# Reference # 170 :	  what tools amp workflow is best for site navigation analysis
# Reference # 171 :	  some doubts about gmm clustering for speaker recognition noob
# Reference # 172 :	  adjustable recommendation system
# Reference # 173 :	  highpaying jobs that make a difference in the world
# Reference # 174 :	  which major to choose for data science
# Reference # 175 :	  visualization how to do principle components but with a special dimension
# Reference # 176 :	  how would you organize this data and load it into pandas
# Reference # 177 :	  kmeans question on pca reduced dataset using pythong scikit learn
# Reference # 178 :	  internship recruitment task
# Reference # 179 :	  how to become a certified data scientist at harvard university
# Reference # 180 :	  looking for advice on internships and universities specially if your are from south america like me d
# Reference # 181 :	  does an appropriate job title exist
# Reference # 182 :	  career advice how difficult is to move from software engineer to a nlp engineer role
# Reference # 183 :	  ml for stock prediction
# Reference # 184 :	  how much linear algebra do you use on a day to day basis
# Reference # 185 :	  r python vs r vba vs r java
# Reference # 186 :	  some help with imitation learning
# Reference # 187 :	  i would like to know your opinion
# Reference # 188 :	  looking for constructive feedback on my machine learning data science focused youtube channel
# Reference # 189 :	  making the jump from manager to director
# Reference # 190 :	  is sas really the best tool for sql joining local tables with database tables
# Reference # 191 :	  is analytics for me even though i am not a hardcore math nerd
# Reference # 192 :	  vanishing utms
# Reference # 193 :	  help with implementing a recommendation system on a website python based flask
# Reference # 194 :	  working in data analytics vs infrastructure
# Reference # 195 :	  chances of getting a remote job as a data analyst as a recent grad with little experience
# Reference # 196 :	  my gan cannot overfit to a single image
# Reference # 197 :	  i am a year old implementation analyst i do data stuff in excel i want to pivot to data science how transferable are my skills and where should i begin
# Reference # 198 :	  ms in statistics need advice
# Reference # 199 :	  need advice on how to get started with ds i can code and previously a cae engineer
# Reference # 200 :	  any ideas on how to better visualize this
# Reference # 201 :	  visual nlp notebook tested by writers
# Reference # 202 :	  when to get rid of old jobs on resume
# Reference # 203 :	  how would you deliver a briefport done on a statistical analysis of million data points
# Reference # 204 :	  is it possible to get into a data science program with no cs background
# Reference # 205 :	  how is error evaluated in an unsupervised neural network with no gan or human intervention
# Reference # 206 :	  question for academics how would an online masters be viewed by potential phd supervisors
# Reference # 207 :	  is ga event tracking useless for service businesses
# Reference # 208 :	  scalable multioutput nn with keras in r
# Reference # 209 :	  how value relevant or absolute is sciem in the data science process
# Reference # 210 :	  python i opensourced dikt a library to dump and read dictionaries out of memory thus allowing you to access values without loading large files in memory
# Reference # 211 :	  i want to learn how to make a speaker identification system
# Reference # 212 :	  hi data science noob looking to learn the field any advice on skill sets i should work on
# Reference # 213 :	  finding the best distribution model to fit my data
# Reference # 214 :	  things i learned while building machine learning web app
# Reference # 215 :	  introductory books resources
# Reference # 216 :	  suggestions on a starting laptop to get into data science hris
# Reference # 217 :	  to anyone who is a professional mldl engineer or works in an equivalent field i have a question
# Reference # 218 :	  modeling help need help finding a technique for seasonal forecasting that assumes smooth pattern
# Reference # 219 :	  is understanding os and computer hardware helpful as a data scientist
# Reference # 220 :	  using training data and testing data in a shared task
# Reference # 221 :	  help deciding whether to renege an offer or leave
# Reference # 222 :	  time dependent vs time independent cross validation
# Reference # 223 :	  sequential conversation datasets
# Reference # 224 :	  tutorials looking for a quick crash course in convolution neural networks
# Reference # 225 :	  getting into the field of data science
# Reference # 226 :	  how valuable is arealtime brick and mortar transaction data
# Reference # 227 :	  looking for career guidance
# Reference # 228 :	  how pvdbow works
# Reference # 229 :	  is ml suited for simple floor planning
# Reference # 230 :	  virtual meetup intro to deep learning with pytorch lightning
# Reference # 231 :	  how can i get into machine learning with a undergraduate degree in a nontechnical discipline
# Reference # 232 :	  dataset published crossword puzzles
# Reference # 233 :	  is it possible to do this
# Reference # 234 :	  i created an autoupdating kaggle dataset that collects highfrequency market data updates daily related trading notebooks
# Reference # 235 :	  which course will be more beneficial for an aspiring data scientist derivative markets and discrete time finance or ordinary differential equations
# Reference # 236 :	  how should i start
# Reference # 237 :	  websites for data science interviews prep
# Reference # 238 :	  help comparing leads and visitors
# Reference # 239 :	  looking for an sme running chartio to help with a migration project pro bono
# Reference # 240 :	  what to do when you only have categorical predictors
# Reference # 241 :	  grad school choice advice
# Reference # 242 :	  data science for africans
# Reference # 243 :	  question on variational autoencoders
# Reference # 244 :	  advice for newbies trying to break inremove the data analyst sql python r tableau from your linkedin headline
# Reference # 245 :	  maths for ml
# Reference # 246 :	  drivendata vs kaggle
# Reference # 247 :	  new to pandas data science with python question on how to go about analyzing a data set in a certain way
# Reference # 248 :	  can my simplified version of lottery be predicted by a neural network
# Reference # 249 :	  education guidance
# Reference # 250 :	  imdb movies reviews dataset on kaggle
# Reference # 251 :	  selecting a data science degreecertification program
# Reference # 252 :	  data science in the digital marketing field
# Reference # 253 :	  need help with dealing with some data
# Reference # 254 :	  whats the best way to get familiar with this data job assessment challenge
# Reference # 255 :	  following up a masters in data science after a chemical engineering bachelor
# Reference # 256 :	  linear regression in python
# Reference # 257 :	  data science courses for beginner
# Reference # 258 :	  need career advice for datascience
# Reference # 259 :	  advanced business analytics degrees
# Reference # 260 :	  how many times to augment each image in training set
# Reference # 261 :	  r v python does the language i choose matter for this project
# Reference # 262 :	  building an api query language for rich data like images and video
# Reference # 263 :	  jump in paid search sessions organic search sessions dead
# Reference # 264 :	  career advice for data governance position as first job
# Reference # 265 :	  how to circumvent seasonal use in data analyses
# Reference # 266 :	  what degree do i need for what i want to do
# Reference # 267 :	  joining firm company culture concern
# Reference # 268 :	  researchers from nankai and stanford propose deepdrug a python based deep learning framework for drug relation prediction
# Reference # 269 :	  can someone please comment on my model results
# Reference # 270 :	  good books for learning data science python and r
# Reference # 271 :	  credit card app
# Reference # 272 :	  how much math really needed for machine learning engineers in the industry
# Reference # 273 :	  help with automation process
# Reference # 274 :	  what is the right way to go about progressing in a data science career
# Reference # 275 :	  prerequisites of data science field
# Reference # 276 :	  retail analytics why a certain product for a certain region overperforms
# Reference # 277 :	  question about neural networks
# Reference # 278 :	  need helpadvise phrasetoken labeling
# Reference # 279 :	  help im going to school for data science but dont know any math
# Reference # 280 :	  using statisticscoding in my ppc job
# Reference # 281 :	  can you help me with a job posting is this reasonable
# Reference # 282 :	  phd in econs to data science
# Reference # 283 :	  transitioning from big data hadoop engineer to data scientist
# Reference # 284 :	  need advice on contentbased and contentaware recommendation systems
# Reference # 285 :	  new to machine learning i have got weighted dice two red two blue and two green each roll i pick one of each color and know the sum of the three dice but not the individual result of any one die how can i determine each die is weights
# Reference # 286 :	  do i do a fellowship for the federal government or do a phd
# Reference # 287 :	  apprentice data analyst at a multinational organisation in terms of next steps for my career where do i stand
# Reference # 288 :	  looking for german datasets with thousands of categories and multiple related questions
# Reference # 289 :	  interested to hear thoughts on the new google data analytics certificate for a job switch google hiring consortium
# Reference # 290 :	  resources for architecting a simple neural network or other ai concepts that may be better for my application
# Reference # 291 :	  how much does loss function can decrease per epoch
# Reference # 292 :	  i am frustrated i didnt learn anything during my internship
# Reference # 293 :	  my road as a psychology major to data scientist
# Reference # 294 :	  what to do when you know how to program in r but you majored in political science
# Reference # 295 :	  advise on how to proceed towards a data science career path
# Reference # 296 :	  what are my options within the data analysisscience field details inside
# Reference # 297 :	  please critique my resume self taught applying to entrylevel data analyst positions
# Reference # 298 :	  a fine line of what data science is
# Reference # 299 :	  first data scientist job after experience in other engineering field how to succeed
# Reference # 300 :	  failed data science career
# Reference # 301 :	  which project would you choose if you were me
# Reference # 302 :	  how to enable ondemand model trainining with sagemaker
# Reference # 303 :	  google analytics amp segment
# Reference # 304 :	  understanding timevec
# Reference # 305 :	  an introduction to natural language processing
# Reference # 306 :	  while building a tfidf determining a good balance between max and min document frequency
# Reference # 307 :	  nontechnical books about data science
# Reference # 308 :	  could a model built with leaky data still be ok to use in production
# Reference # 309 :	  checking if convolutional weights are normally distributed is the bias representative of a trend in my data
# Reference # 310 :	  what do you think of a data science bachelors
# Reference # 311 :	  landing a job with sql
# Reference # 312 :	  help with jobcareer please any advice i would love tyvm
# Reference # 313 :	  how import is domain to a data scientistml engineer
# Reference # 314 :	  get predictions for all users with surprise svdpp algorithm
# Reference # 315 :	  seeking advice for learning path
# Reference # 316 :	  is it possible to learn data mining in a week
# Reference # 317 :	  what is the best path for me if my endgoal is nlp here are a few resources i have found that i would like feedback on
# Reference # 318 :	  data science pc build
# Reference # 319 :	  ga is reporting spam referrals even though i do not have the tracker id script loaded
# Reference # 320 :	  struggling with leadership role
# Reference # 321 :	  researchers introduce alpa a compiler system for distributed deep learning built on top of machine learning parallelization approaches that automatically generates parallel execution plans covering all data operator and pipeline parallelisms
# Reference # 322 :	  how do you use stored regression residuals as movingaverage error terms and then forecast
# Reference # 323 :	  while transitioning from another field what is the inherent value of a specific degree in ds
# Reference # 324 :	  feature engineering building a feature of previous transactions from monthly transaction records
# Reference # 325 :	  predicting the sunrise
# Reference # 326 :	  change in prototxt does not translate to a change in the network
# Reference # 327 :	  help finding income by county and corresponding covid rates
# Reference # 328 :	  looking for a paid personal teacher
# Reference # 329 :	  career advice science phd
# Reference # 330 :	  what would you say is an intermediate level of proficiency in rpythonsqlmlpowerbitableau for someone aiming for a job at little bit above entrylevel ie when the job description asks for someone with demonstrable experience in these skills ie not entry level
# Reference # 331 :	  transition from engineering to data science
# Reference # 332 :	  quality inspection in manufacturing using deep learning based computer vision
# Reference # 333 :	  basic questions about the regularization term
# Reference # 334 :	  thunder precisionrecall curve bad results on classification data set
# Reference # 335 :	  how would you go about combining two classifiers one cnn and one rf
# Reference # 336 :	  are neural networks being overused
# Reference # 337 :	  anyone good at statistics or experimental design
# Reference # 338 :	  categorizing email structures text recognition
# Reference # 339 :	  anyone interested in learning use machine learning techniques programming frameworks data processing pipelines and deployments and getting paid to do it for small dividends for this round it is figuring out how to use google brain is very prominent tensortensor library
# Reference # 340 :	  statistics or cs msc for data science
# Reference # 341 :	  for data scientists and analysts could you explain from start to finish what is the etl process for big data projects what is the process of data cleaning and loading and how do you do this with big data
# Reference # 342 :	  employee satisfaction live data
# Reference # 343 :	  which is the best master thesis topic for a career in data science
# Reference # 344 :	  linear vs logarithmic regression
# Reference # 345 :	  offered an entry level data science role after a decade of experience in statistics fair
# Reference # 346 :	  need some help creating my job description
# Reference # 347 :	  text analytics
# Reference # 348 :	  new library multiple imputation by random forests in python
# Reference # 349 :	  problems with output from keras cnn
# Reference # 350 :	  advice for a bench scientist looking to transition to data science
# Reference # 351 :	  at the end of my rope in my current position any advice for getting out of it xpost from rcscareerquestions
# Reference # 352 :	  help with eer diagram point out mistakes andor what can be done better ill delete this post if this is not allowed in the subreddit
# Reference # 353 :	  breaking into a career in data sciences
# Reference # 354 :	  node red vs apache nifi xpost rbigdata
# Reference # 355 :	  what kind of data scienceanalyst jobs i can get in india with my current knowledge
# Reference # 356 :	  polarization powerful billionaires and the eroding effects of inequality rahaf harfoush
# Reference # 357 :	  on confusion in regards to classrbms
# Reference # 358 :	  discord for ng is ml course coursera
# Reference # 359 :	  question about linking records
# Reference # 360 :	  resume critique recent math phd seeking data analyst data scientist positions
# Reference # 361 :	  data science machine learning courses advice
# Reference # 362 :	  does anyone need a machine learning mentor
# Reference # 363 :	  advice needed
# Reference # 364 :	  data science for biomedical research and genomics python or r
# Reference # 365 :	  best cloud setup for always on apps that scraperetrieve then store data
# Reference # 366 :	  best algorithm for anomaly detection unsupervised time series data
# Reference # 367 :	  what data do you care about
# Reference # 368 :	  how do u rate matlab for data science applications
# Reference # 369 :	  should i just quit
# Reference # 370 :	  issue with solving cartpole using deep rl
# Reference # 371 :	  trying to scrape boxing bout dataset
# Reference # 372 :	  seeking for a career advise in data science
# Reference # 373 :	  do more aiml related ds roles tend to ignore people that have had a more data analyst role as a starting career
# Reference # 374 :	  most common custom dimensions metrics and events for ecommerce sites
# Reference # 375 :	  confused on comparing policies how reinforcement learning
# Reference # 376 :	  interview advice please
# Reference # 377 :	  im thinking of possible transitioning to data science but i have a lot of doubts about the feasibility
# Reference # 378 :	  looking for advice on internships and universities specially if you are from south america like me d
# Reference # 379 :	  syncing google analytics to tableau
# Reference # 380 :	  handling time series window functions in data science interviews
# Reference # 381 :	  which laptop for aws for data science and machine learning
# Reference # 382 :	  advice about teammates
# Reference # 383 :	  networking for data scientists on linkedin properly
# Reference # 384 :	  looking for a partner to work on python projects
# Reference # 385 :	  super accurate duplicate matching
# Reference # 386 :	  group vs solo final project
# Reference # 387 :	  need help choosing an online course
# Reference # 388 :	  creating a panel dataset with time country and industry helping out a very stressed economic student
# Reference # 389 :	  starting a new data analyst job soon one year out of graduation and worried about keeping up
# Reference # 390 :	  comparison of saturation rate vs desaturation rate of a meme
# Reference # 391 :	  educationcareer just got laid off and looking to get a ms in ds seeking for advice
# Reference # 392 :	  best database to store manage amp productize scraped data
# Reference # 393 :	  questions on the new google dashboard
# Reference # 394 :	  not sure how to charge
# Reference # 395 :	  how to create and use open source machine learning pipeline
# Reference # 396 :	  hard time remembering git commands try gitutor
# Reference # 397 :	  so i have an interview for a business intelligence analytics position coming up and debating on using my real world experience in the interview
# Reference # 398 :	  how are arimamodels actually used in practice
# Reference # 399 :	  how to estimate an impact of a sales team
# Reference # 400 :	  intel edge ai for iot developers nanodegree program
# Reference # 401 :	  options to find the most similar question in a dataset of questionanswer pairs
# Reference # 402 :	  google ai introduces performer a generalized attention framework based on the transformer architecture
# Reference # 403 :	  data scientist or data analyst
# Reference # 404 :	  what to do in analytics career mid level
# Reference # 405 :	  practice exercises while learning ds
# Reference # 406 :	  analyzing survey responses determining which questions drive the overall response
# Reference # 407 :	  future plans are settling in the uscanada with a data science job currently have a relevant offer from a consulting firm should i get some experience before moving
# Reference # 408 :	  what does a good scikitlearn workflow look like
# Reference # 409 :	  feeding mri data into spherical cnn d
# Reference # 410 :	  tensorflow object detection classification loss with one class
# Reference # 411 :	  about to start applying for jobs months after getting my current job
# Reference # 412 :	  my team wants me to hold a presentation about data and the insights you can win from statistical methods how would i best structure this
# Reference # 413 :	  where do i stand as an analyst
# Reference # 414 :	  help with a statisticsproduct managementab scenario
# Reference # 415 :	  best practicessoftware for transcribing data
# Reference # 416 :	  tensorflow rnn model works with lstm cell but returns nan with gru cell
# Reference # 417 :	  how do you measure experience pain points customers have in interactions with customer care
# Reference # 418 :	  how far can i go in data analytics with just numpypandas sql powerbi and alteryx
# Reference # 419 :	  analyzing game stats with python and sql personal project
# Reference # 420 :	  data science certificates what is the best
# Reference # 421 :	  advice on the interview process
# Reference # 422 :	  data science in practice post
# Reference # 423 :	  data scientist vs data artist
# Reference # 424 :	  seeking advice
# Reference # 425 :	  job title and background check
# Reference # 426 :	  my ultimate guide to web scraping
# Reference # 427 :	  how can i know which robot will win based on match data
# Reference # 428 :	  what is the best way to predict a value based off two variables
# Reference # 429 :	  advice on how to break into the market while i am doing a masters no prior experience
# Reference # 430 :	  question how do you review predictions and update models efficiently
# Reference # 431 :	  what are my chances of getting a data science job after bootcamp
# Reference # 432 :	  women is summit in nyc
# Reference # 433 :	  any advice for the project work that i have to do
# Reference # 434 :	  feasibility of running an ml model on phone hardware
# Reference # 435 :	  cuda and cuda installed ubuntu
# Reference # 436 :	  edux course in business analytics from columbua university micromasters
# Reference # 437 :	  best way to create office file management guidesprocedures
# Reference # 438 :	  tensorflow cnn mapbox d real life simcity
# Reference # 439 :	  downloading public pdf files from us state department for an analytic project any way to expedite the download
# Reference # 440 :	  help required in understanding how the error of a convolutional layer is calculated when the filter and delta of next layer have differing dimensions
# Reference # 441 :	  simple vs game to implement a rl agent
# Reference # 442 :	  need advice regarding data science and engineering field
# Reference # 443 :	  looking to get into the career of data analysis i have a history of psychology research with stats what program should i learn to make myself competitive
# Reference # 444 :	  elevation profile data for the entire earth
# Reference # 445 :	  how do i find interval for rgb mask using an existing dataset
# Reference # 446 :	  can i play around with a mock version of google analytics would really appreciate your advice
# Reference # 447 :	  suggestions for someone thinking of doing a masters in gisremote sensing
# Reference # 448 :	  how do i make the most money in this field
# Reference # 449 :	  perfect free data tools for anyone with a website
# Reference # 450 :	  how to combat burntout feelings in data science
# Reference # 451 :	  can i be an analyst if i have a degree in herbology or better known as pharmacy from durmstrang institute
# Reference # 452 :	  anonymized meetmindful leak subset k rows
# Reference # 453 :	  question about breaking into data science later in career
# Reference # 454 :	  friends and i are sick of online tutorials so were running a group for learning data science by playing competitive team games is this a cool idea
# Reference # 455 :	  building a crystal ball of the world unseating capitalism and creating a new world order with prof dirk helbing
# Reference # 456 :	  what do you love about data science
# Reference # 457 :	  what standards or tools for describing visualizing archiving metadata for analytics data sets
# Reference # 458 :	  data organization for textual analysis of song lyrics
# Reference # 459 :	  announcing hora an blazingly fast approximate nearest neighbor search algorithm library
# Reference # 460 :	  understanding followed by and immediately followed by in segments
# Reference # 461 :	  data science statistics or middle ground eu msc
# Reference # 462 :	  early stopping for neural nets
# Reference # 463 :	  best undergraduate degree for data science graduate programs
# Reference # 464 :	  critique my resumewebsiteportfolio
# Reference # 465 :	  math question from a nonmath person in the topic of norms
# Reference # 466 :	  excel alternative for processing large amounts of social media data
# Reference # 467 :	  train validation test and decision threshold choice in classifiers
# Reference # 468 :	  need help finetuning a simulation i am trying to run on r solving the sided dice problem
# Reference # 469 :	  text analysis in python for social scientists with code free pdf through march
# Reference # 470 :	  data governance tool what to look for dqlabsai
# Reference # 471 :	  a budding data scientist needs career advice
# Reference # 472 :	  any advice on implementing deep learning recommendation system
# Reference # 473 :	  how to tell keras which column in a pandas dataframe to predict
# Reference # 474 :	  what are your thoughts or opinions for someone starting a data analytics consulting business
# Reference # 475 :	  is there a standard approach for utilizing test validate and train sets when performing classification problems
# Reference # 476 :	  general advice on looking for specific patterns in data
# Reference # 477 :	  question about terminology what are activations
# Reference # 478 :	  largest covid korea dataset with unparalleled patient details
# Reference # 479 :	  set up a sidebusiness at home
# Reference # 480 :	  senior decision scientist job prospects against data scientist passion
# Reference # 481 :	  what are examples from your working experience when domain knowledge is super important
# Reference # 482 :	  a question
# Reference # 483 :	  resources for understanding of tensorflow internals
# Reference # 484 :	  rescaling a dataset with consistent feature with dtw
# Reference # 485 :	  any ml engineers here i will be grateful for some academic advice
# Reference # 486 :	  creating a goal funnel
# Reference # 487 :	  my attempt at explaining what artificial intelligence is
# Reference # 488 :	  graduating with no experience
# Reference # 489 :	  starting out tips
# Reference # 490 :	  question about combining two datasets with different time step measurements
# Reference # 491 :	  data scientist partner program
# Reference # 492 :	  data pipeline vs middleware javabased microservices for data intensive use cases
# Reference # 493 :	  professor cuts me off mid presentation and dismissed my idea how common is this in industry with management
# Reference # 494 :	  lstm data shape amp binary classification help
# Reference # 495 :	  google analytics at the frontend or the backend how to handle what a user is searching on my website
# Reference # 496 :	  so it turns out that i have accidentally went down the data science path i am looking for advice
# Reference # 497 :	  how do anchors in region proposal networks work
# Reference # 498 :	  d understanding einsum for deep learning implement a transformer with multihead selfattention from scratch
# Reference # 499 :	  is it hard to be an ml expert with just a bs or ms
# Reference # 500 :	  is it possible to use a customdefined decision tree classifier in scikitlearn
# Reference # 501 :	  gdelt project
# Reference # 502 :	  facebook pixel integration help is it possible to add pixels already installed on a website to a client is events manager on fb ie pixel helper
# Reference # 503 :	  can datacentric approach be applied to featurecentric approach
# Reference # 504 :	  ms in analytics or mscs
# Reference # 505 :	  data science allocation at a startup
# Reference # 506 :	  people whove worked at multiple companies how has the different levels of emphasis on data governance across those organisations influenced your enjoyment and success with ds projects
# Reference # 507 :	  who am i
# Reference # 508 :	  two questions where to start for the knowledgeable beginner is there any controls based machine learning
# Reference # 509 :	  model for classification of common misspellings
# Reference # 510 :	  becoming more analytical
# Reference # 511 :	  help me to learn machine deep learning ai pls
# Reference # 512 :	  distributing python tools as executables to nontechnical users
# Reference # 513 :	  desktop app for reading mathstats pdfs and taking notes
# Reference # 514 :	  regarding inter class confusion for a classification model
# Reference # 515 :	  manufacturing cycle time prediction
# Reference # 516 :	  two years ago i wrote about my experiences landing my first ds job two years later and through one pandemic here were my painful experiences in landing my second ds job
# Reference # 517 :	  data science and art
# Reference # 518 :	  data scientist without masters or phd
# Reference # 519 :	  how to combine bag of words
# Reference # 520 :	  advice for career in deep learning
# Reference # 521 :	  looking datasets relevant for physics that can be used for parameter estimation
# Reference # 522 :	  i have a few job offers i do not know which one will be best for a data science career
# Reference # 523 :	  ncsu vs csuf vs uidaho for ms in statistics
# Reference # 524 :	  any great textbooksresources on time series analysis for python
# Reference # 525 :	  should i purchase a gaming or cheap laptop for deep learning or not
# Reference # 526 :	  gans for baseball simulations
# Reference # 527 :	  courses as good as andrew ng is ml from recent years
# Reference # 528 :	  request i need a screen shot of data science at work
# Reference # 529 :	  what feature reductionselection routine
# Reference # 530 :	  help with tfidf transformer
# Reference # 531 :	  started new data science position months ago and thinking of leaving
# Reference # 532 :	  my friend says doing a ds internship in college is a bad idea
# Reference # 533 :	  using the kolmogorovsmirnov test statistics for measuring concept drift
# Reference # 534 :	  i am a programmersysadmin looking to get into data science where do i start
# Reference # 535 :	  it or cs degree for career switch to data analytics
# Reference # 536 :	  am i in over my head thinking that i can go into data science without having a background in it
# Reference # 537 :	  data analysis is not business intelligence
# Reference # 538 :	  any suggestions on how to get into stock market analysis
# Reference # 539 :	  how to do forecasting accuracy for data
# Reference # 540 :	  dataops vs legacy data governance and how is broken in the ml era
# Reference # 541 :	  consulting rates on east coast
# Reference # 542 :	  machine learning for an error prediction of a best first search maze solving algorithm
# Reference # 543 :	  advice on how to run a nlptext analytics course for a student organization
# Reference # 544 :	  remote data science work
# Reference # 545 :	  news the microsoft ai powerhouse and trends in ml
# Reference # 546 :	  system analytics or development operations
# Reference # 547 :	  which programming languages except python and r would you recommend to learn for data science machine learning
# Reference # 548 :	  advice on jobs in research data and statistics
# Reference # 549 :	  total beginner is pattern matching relevant to machine learning
# Reference # 550 :	  churn
# Reference # 551 :	  request for interview for my fyp
# Reference # 552 :	  success stories from dataquest
# Reference # 553 :	  who should not go into data science
# Reference # 554 :	  error lower bound and label uncertainty
# Reference # 555 :	  how important is cloud computing for datascience students
# Reference # 556 :	  question about analytic services
# Reference # 557 :	  deeplearningai how to build a complete trigger warning training data set sequential models week assignment
# Reference # 558 :	  mathematics or computer science where to spend efforts
# Reference # 559 :	  looking to switch
# Reference # 560 :	  advice for a mathematical moron
# Reference # 561 :	  questions about pytorch chatbot tutorial
# Reference # 562 :	  which fastai course should i tackle first
# Reference # 563 :	  high school student strong in maths weak in computers is data science an option for me
# Reference # 564 :	  advice for entering ml as a medical student
# Reference # 565 :	  can you use linear regression in this case pointers and years
# Reference # 566 :	  best source for dataset concerning exportimports between china and partners countries since
# Reference # 567 :	  skills to transition from data scientist to ml engineer
# Reference # 568 :	  any recommendations for data communicationvisualisation courses
# Reference # 569 :	  location specific segments in ga other than metro or city
# Reference # 570 :	  advice moving soon trying to decide best city for datascience jobs
# Reference # 571 :	  i am writing an article on the necessity of specialisation in data science and could use your input
# Reference # 572 :	  totally out of my league here but
# Reference # 573 :	  federated learning with keras
# Reference # 574 :	  searching code examples and best practices in notebooks
# Reference # 575 :	  automatized data science
# Reference # 576 :	  disinformation archive cataloging misinformation on the internet
# Reference # 577 :	  finding weights to selected features
# Reference # 578 :	  first ds interview
# Reference # 579 :	  analyzing sales data
# Reference # 580 :	  nlp for contract review
# Reference # 581 :	  advice for career talk
# Reference # 582 :	  startup with more pay or a big consulting firm with less pay but more opportunities
# Reference # 583 :	  stumped by an interview question
# Reference # 584 :	  last minute prep for research position interview
# Reference # 585 :	  does a informatics scientist or lab digitalization role count as relevant experience if i eventually want to get into data science
# Reference # 586 :	  data science career advice amp mentoring
# Reference # 587 :	  line chart that shows whether you remain between two values python or excel
# Reference # 588 :	  transfering to b analyst d analyst d sci master without prior exp
# Reference # 589 :	  optimizing parameters of fully connected layers
# Reference # 590 :	  manually extracting rules from a decision tree
# Reference # 591 :	  has anyone tried the new gtag framework in google analytics yet
# Reference # 592 :	  deep learning help
# ...
# Reference # 1048 :	  math needed for data science
# Reference # 1049 :	  need advice in new analyst job
# Reference # 1050 :	  any good book for data analytic reports
# Reference # 1051 :	  any thoughts on tomi mester from data
# Reference # 1052 :	  how do autoencoders reduce features
# Reference # 1053 :	  best guess identification of previously seen entities with imperfect data
# Reference # 1054 :	  why is the activation function important for gradient descent in nn
# Reference # 1055 :	  thoughts on san diego state statistics data science bs
# Reference # 1056 :	  recommend mac software for drawing complex chartsmindmaps
# Reference # 1057 :	  how big are your teams and for what size company
# Reference # 1058 :	  my job candidate takehome feels like unpaid work am i wrong for just saying no thanks
# Reference # 1059 :	  does adwords give transaction ids for conversion like google analytics
# Reference # 1060 :	  help questions on training a pretrained model on a very different dataset
# Reference # 1061 :	  ga and multiple source cost data other options
# Reference # 1062 :	  hiring data scientist biotech in cambridge ma
# Reference # 1063 :	  foundation for success in data science
# Reference # 1064 :	  resume review entry level data scientist ml related position
# Reference # 1065 :	  acs data what pumas are in the greater boston msa
# Reference # 1066 :	  switching bi tools
# Reference # 1067 :	  help with visualization for showing the mean of rsquared for different categories
# Reference # 1068 :	  ml competitions fun open teams is there such a thing
# Reference # 1069 :	  bsc in ai or bcom mathematics
# Reference # 1070 :	  currently a data analyst a bit concerned at the next step in my learning need guidance what should i be doing
# Reference # 1071 :	  self study suggestions please answer
# Reference # 1072 :	  get the contour coordinates in a final predicted mask
# Reference # 1073 :	  a little thought about the unification of dynamic and static graphs
# Reference # 1074 :	  help with machine learning
# Reference # 1075 :	  dealing with complexity
# Reference # 1076 :	  machine learning heavy jobs
# Reference # 1077 :	  how to improve my data science cv to get my first job investing free time given by coronavirus restrictions
# Reference # 1078 :	  interview preparation advice
# Reference # 1079 :	  data engineering lims
# Reference # 1080 :	  help getting dataset imported via into tidy data format
# Reference # 1081 :	  google analytics need help passing referral path in crossdomain tracking
# Reference # 1082 :	  conditioning a vae on an image the image itself is the condition
# Reference # 1083 :	  tips for teaching upper level undergrad data science course
# Reference # 1084 :	  setting up a new deep learning machine any tips from the community
# Reference # 1085 :	  would you quit your job if you were not allowed to use sql
# Reference # 1086 :	  college gt data scientist need advice
# Reference # 1087 :	  how to train a nerf in seconds explained instant neural graphics primitives with a multiresolution hash encoding minute paper summary by casual gan papers
# Reference # 1088 :	  likelihood function for binary classification with some incorrectly labeled data xpost rhomeworkhelp
# Reference # 1089 :	  i need help understanding a paper
# Reference # 1090 :	  career advice golden handcuffs in the federal government usa
# Reference # 1091 :	  overfitting questions regarding dl
# Reference # 1092 :	  i have my first data related assignment at work advice appreciated
# Reference # 1093 :	  what college majors or disciplines should i do to go into data science
# Reference # 1094 :	  doing data science in ee department good idea
# Reference # 1095 :	  realesrgan training realworld blind superresolution with pure synthetic data by xintao wang et al
# Reference # 1096 :	  new ideas for ml healthcare projects portfolio and capstones and advice on my ideas
# Reference # 1097 :	  need help tensorflow problem with optimizers
# Reference # 1098 :	  which skill should i focus on to get into any data science role as soon as possible
# Reference # 1099 :	  really would like some help or advice as a noob in web analytics
# Reference # 1100 :	  the data careers space domains and intersections
# Reference # 1101 :	  time series state results
# Reference # 1102 :	  bored data analyst wants to get into data science but worried i lack the background knowledgeskills
# Reference # 1103 :	  certificate in data science
# Reference # 1104 :	  what kind of data structure should i use to store mixed data beginner
# Reference # 1105 :	  how to make a data science project from scratch new series
# Reference # 1106 :	  what was it like first starting as an analyst out vs now
# Reference # 1107 :	  what types of questions and coding samples are normal to expect when one is interviewing or thinking about prepping for a data science job interview at a manager or director level
# Reference # 1108 :	  data scientist offer at consulting firm should i accept
# Reference # 1109 :	  question about adding new features w no historical data in nn timeseries
# Reference # 1110 :	  improving keras accuracy
# Reference # 1111 :	  entry level job qualifications
# Reference # 1112 :	  help looking for freelancing jobs
# Reference # 1113 :	  adviceguidance needed for a case study for a data science interview
# Reference # 1114 :	  ds masters subsequent phd studies
# Reference # 1115 :	  will machine learning ever be in the domain of web development
# Reference # 1116 :	  best model for recommending articles based on previous rating of articles read by you
# Reference # 1117 :	  pulling uptodate data from small websites in the outdoor industry api webscraping other best method
# Reference # 1118 :	  all digitized texas appeals court cases since
# Reference # 1119 :	  ga search related use case
# Reference # 1120 :	  i think i have got some elements of neural networks confused in my head can someone help me clarify
# Reference # 1121 :	  call center analytics average vs median vs mode vs something else
# Reference # 1122 :	  confusion about the transposed convolution implementation in caffe
# Reference # 1123 :	  first data science job with focus around sap shana
# Reference # 1124 :	  are ms in data science programs actually viablevaluable in industry when compared to graduate degrees in statistics physics math cs etc
# Reference # 1125 :	  how often do you use fancy regression methods
# Reference # 1126 :	  anyone pull news related tweets from the twitter streaming api what kind of volume can i expect
# Reference # 1127 :	  questions about automating etl from databases to tableau never done any practical work with real databases before so i was hoping for some clarification
# Reference # 1128 :	  help with class project
# Reference # 1129 :	  phd machine learning engineering or data science what should i do next
# Reference # 1130 :	  speed up labeling by detecting similar objects in a neural network
# Reference # 1131 :	  question versatility of computational biology
# Reference # 1132 :	  data science boot camps
# Reference # 1133 :	  i would like to classify html pages into groups right approach
# Reference # 1134 :	  how to switch from data engineering to data science
# Reference # 1135 :	  google analytics vs tag manager vs custom javascript for tracking web traffic
# Reference # 1136 :	  microsoft access jet sql
# Reference # 1137 :	  question about news aggregating grouping
# Reference # 1138 :	  how does multihead attention on multiple attention axes works
# Reference # 1139 :	  categorization accuracy in competition
# Reference # 1140 :	  software engineering or data analyst internship for machine learning career
# Reference # 1141 :	  how much direct traffic is alright to start working with proper attribution modeling
# Reference # 1142 :	  splitting images between train and test
# Reference # 1143 :	  aiming for accounting positions only in the short run
# Reference # 1144 :	  entry level resume critic
# Reference # 1145 :	  is there any online dictionary or thesaurus that helps you to go between coding languages
# Reference # 1146 :	  coursera certificates
# Reference # 1147 :	  does anyone follow the rstudio blog
# Reference # 1148 :	  final year project reinforcement learning in texas holdem
# Reference # 1149 :	  good references for matrix calculus
# Reference # 1150 :	  opinions about choosing an specific master is thesis
# Reference # 1151 :	  finance vs tech
# Reference # 1152 :	  causing memory leaks or something of that sort in tensorflow
# Reference # 1153 :	  task ideas for a spiking neural network
# Reference # 1154 :	  what is your approach in structuring data in a general way
# Reference # 1155 :	  cannot make sense of a high order of disorder means a low level of impurity
# Reference # 1156 :	  any advice on how to clean up a kludge of a python setup
# Reference # 1157 :	  web scrape with beautiful soup
# Reference # 1158 :	  any spatial data scientists out there
# Reference # 1159 :	  questions to answer using the data acquired from a renewable energy home
# Reference # 1160 :	  please help me prune my career decision tree
# Reference # 1161 :	  how to aggregate data for instances that occur over very different time periods
# Reference # 1162 :	  worklife balance
# Reference # 1163 :	  unique events and event goals
# Reference # 1164 :	  python sklearn ocr for survey answers with special characters and
# Reference # 1165 :	  detection blender or similar to generate artificial datasets
# Reference # 1166 :	  retraining as a data scientist best options for me
# Reference # 1167 :	  rate of interesting work for those with an ms vs phd
# Reference # 1168 :	  data analyst masterswill i be over educated and underemployed without experience
# Reference # 1169 :	  linebased image segmentation using deep learning
# Reference # 1170 :	  need help trying to find raw census data for tracts in csv form
# Reference # 1171 :	  tips for a career transition into data science
# Reference # 1172 :	  my internship is troubling me how to not get fired
# Reference # 1173 :	  textbook recommendation for nonstatistical machine learning
# Reference # 1174 :	  d a brief paper review mico mixup cotraining for semisupervised domain adaptation
# Reference # 1175 :	  what is the status of capsule network rampd
# Reference # 1176 :	  is going into data science ideal for ai researchengineering
# Reference # 1177 :	  making the jump
# Reference # 1178 :	  stanford imageparagraphcaptioning dataset confusion
# Reference # 1179 :	  joined a company with an inflated title now what
# Reference # 1180 :	  looking to identify document has having handwriting not ocr
# Reference # 1181 :	  algorithm for optimization problem with discrete number of solutions
# Reference # 1182 :	  p fine tuning openai is gpt model to generate domain names
# Reference # 1183 :	  r google amp deepmind researchers revamp imagenet
# Reference # 1184 :	  building an agnostic nlp pipeline
# Reference # 1185 :	  need some professional help for master thesis data set
# Reference # 1186 :	  crunched deviance residuals
# Reference # 1187 :	  question machine learning and automation tests how can i use it
# Reference # 1188 :	  restricting the output did not improve the loss value of the model evaluation
# Reference # 1189 :	  validating models for individual behavior using aggregate results
# Reference # 1190 :	  can someone define data analysis scientists engineer and architect please
# Reference # 1191 :	  finished isl and applied predictive modeling what can i learn do in a month that can get me an internship
# Reference # 1192 :	  question about spacy ner
# Reference # 1193 :	  how should you plan your day to learn machine learning in days
# Reference # 1194 :	  fb analytics seeking confirmation that filter does what i think it does
# Reference # 1195 :	  helpful advice
# Reference # 1196 :	  how to create your own python toolbox
# Reference # 1197 :	  rnn with multiple different sequence types
# Reference # 1198 :	  documentationuser guide formatting help
# Reference # 1199 :	  what to do after finishing coursera course
# Reference # 1200 :	  data source and gis to use for this problem
# Reference # 1201 :	  what causal inference packages and models do you use
# Reference # 1202 :	  has anyone gone through the insight data engineering fellows program
# Reference # 1203 :	  i started learning data science a few months ago and now i am afraid of touching the keyboard d
# Reference # 1204 :	  ominiscope vs python r
# Reference # 1205 :	  job offer in manufacturingiot
# Reference # 1206 :	  detecting specific events in videos using deep learning
# Reference # 1207 :	  incoming consultant in data scienceanalytics field learning opportunities events to follow books to read podcasts to listen to anything helps
# Reference # 1208 :	  bs in computer science vs master of applied stats for ds jobs
# Reference # 1209 :	  what kind of algorithmic framework can i use to do the following
# Reference # 1210 :	  consulting data scientists how can i publish research based on consulting work for a company
# Reference # 1211 :	  problem with training a gan in tensorflow
# Reference # 1212 :	  applied to data science bootcamps in san francisco what sort of questions should i ask them
# Reference # 1213 :	  does this process make sense finetuning a bert model twice once on mlm and then a second time on a specific task
# Reference # 1214 :	  concerned about automation in machine learning
# Reference # 1215 :	  covid india related ask
# Reference # 1216 :	  r announcing the release of stellargraph version opensource python machine learning library for graphs
# Reference # 1217 :	  advice needed to drop out or not
# Reference # 1218 :	  the only reason i want to further my learning in machine learning
# Reference # 1219 :	  using regression to predict standard error amp confidence intervals
# Reference # 1220 :	  did anyone regret choosing ds as a career or has got disillusioned with it
# Reference # 1221 :	  analysis of faang data engineer job postings indemand skills for data engineers in
# Reference # 1222 :	  ds bosses how do you keep track of your team is projects
# Reference # 1223 :	  looking for guidance training neural net with some features missing
# Reference # 1224 :	  resources for managing ds teams
# Reference # 1225 :	  pursuing ds with no stem background advice for a recent undergrad
# Reference # 1226 :	  introducing gptclient v
# Reference # 1227 :	  text classification by speaker
# Reference # 1228 :	  help with project approach
# Reference # 1229 :	  i have created an android app to help you exploit data about your consumption i would love to hear your feedback
# Reference # 1230 :	  ecommerce website google analytics showing no through traffic after starting page
# Reference # 1231 :	  neural network overfitting from the beginning of training
# Reference # 1232 :	  interview presentation how to connect adtech and martech google adobe
# Reference # 1233 :	  datascience and youtubesocial media analytics
# Reference # 1234 :	  will a cs or ps significantly hurt my chances when applying for an ms in data science
# Reference # 1235 :	  im so sick of corporate morons
# Reference # 1236 :	  masters or work experience
# Reference # 1237 :	  virginia tech cmda for data science
# Reference # 1238 :	  google analytics question tracking multiple domains
# Reference # 1239 :	  backpropogation confusion
# Reference # 1240 :	  forecasting conference
# Reference # 1241 :	  there are plenty of fields that have not even scratched the surface of data science yet
# Reference # 1242 :	  bachelor of data science vs computer sciencemaths
# Reference # 1243 :	  career opinion ds in tech vs nontech companies
# Reference # 1244 :	  is reinforcement learning feasible for a beginnerish
# Reference # 1245 :	  a review of python deep learning computer vision courses warning long
# Reference # 1246 :	  how to best identify if a social post is written by a doctor vs patient
# Reference # 1247 :	  what are some mp and temporal data or time series papers you like
# Reference # 1248 :	  how to preprocess at scale
# Reference # 1249 :	  neurips min talk deepsvg a hierarchical generative network for vector graphics animation
# Generate Time elapsed: 1.2149384021759033 seconds.

# %%
rouge = evaluate.load("rouge")
rouge_results = rouge.compute(predictions=candidates, references=references)

pd.DataFrame([rouge_results])
# Out:
#      rouge1    rouge2    rougeL  rougeLsum
# 0  0.184472  0.051011  0.165052   0.165165

# %%
bleu = evaluate.load("bleu")
bleu_results = bleu.compute(predictions=candidates, references=references)

pd.DataFrame([bleu_results])
# Out:
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
#        bleu  \
# 0  0.029681
#
#                                                                                precisions  \
# 0  [0.18707643814026792, 0.05043706293706294, 0.015996074582924437, 0.005141962888441762]
#
#    brevity_penalty  length_ratio  translation_length  reference_length
# 0              1.0      1.023883               12690             12394

# %%
# Combine Candidates and References

df = pd.DataFrame({'ref_post': references_post,
                   'ref_title': references,
                   'candidate_title': candidates
                   })
# Inspect DF
print(df.head())

# Export to CSV
df.to_csv('drive/My Drive/W266/t5_results.csv', index=True, index_label='Index_ID')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ref_post  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    some background i have been learning python for over a year now and i know some sql a bit of r and i have completed some small projects using data science data engineering practices i also know how to work in excel but i do not really have experience using databases i am totally willing to make the time and money investment in something like a bootcamp and i have the means to do fulltime training but i do not want to do this if there is a better faster way to get into the industry what i really want to know is what can i do that will get me a job in the field asap is there some specific bootcamp that will make this happen if so what are the best bootcamps or some particular tech skill i could learn that would basically guarantee that i am hireable very soon if i something like learned microsoft sql server or tableau and given my other skills would this be likely to get me hired i have been looking into bootcamps like thinkful springboard and data application lab the concern i have about these is actually that i already know a lot of the stuff they teach and i am worried that these will be a waste of time and not elevate me to where i want to be i also worry about it taking months to complete these programs as they estimate i would like to be finished in no more than about months thoughts
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           hi all i have created a python module to extract sngrams which is different from traditional ngrams as it embodies linguistic syntactic trees thus making it less arbitrary than traditional ngrams as it goes without saying quality of input feature affects model performance this will help you improve your model accuracy even further built on language models of spacy it can help especially for text classification information extraction query understanding machine translation question answering systems below is an example from sngramextractor import sngramextractor ampxb sngram_objsngramextractortextmeta_tagoriginaltrigram_flagyes texteconomic news have little effect on financial markets outputsngram_objget_sngram printtext print isngram bigramoutput isnbigram print isngram trigramoutput isntrigram economic news have little effect on financial markets sngram bigram cloud_every has_cloud lining_a lining_silver has_lining sngram trigram has_lining_silver ampxb textevery cloud has a silver lining outputsngram_objget_sngram printtext print isngram bigramoutput isnbigram print isngram trigramoutput isntrigram ampxb every cloud has a silver lining sngram bigram cloud_every has_cloud lining_a lining_silver has_lining sngram trigram has_lining_silver ampxb pypi
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       i am looking at some of the modeling programs the company has been using and there are options to smooth binned data layered linear on bin linear on avg linear on log avg and variable gradient are these methods commonly used in any algorithms i am not sure how i would implement it into r ampxb variable gradient is the most confusing it groups data from neighboring bins with a bin factor being determined the level of smoothing is determined by the radius all bins contribute to the calculation of the bin factor with decreasing weight as the distance from the target bin increases the weight is equal to radius distance radius ampxb once you calculate the overall factor a calculation is performed for each bin weighted by an exposure with various radii and a selected credibility level the calculation that yields the largest distance from is then selected as the factor to be used for that bin ampxb over multiple iterations of the model the factors are blended until the model converges and we receive a final coefficient for that bin ampxb since it is a program i have no clue what is going on in the background to calculate the convergence or what type of model this is it ends up being a multiplicative model so i am guessing it is a log linked glm
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             let is say i have created a fraud detection model i already have a process that cleans the data and stores the trainable data in a table in a database and now i want to set up a recurring job that retrains my model every x time period how do people go about this when we want to retrain the model does not that data have to be loaded into the environment that the new model is going to be retrained i guess i am confused at how exactly the model takes the data from the database and starts training on it do people use spark to load it into the environment with the modeltobe then start the retraining process does not that mean that the retraining environment has to have enough space to cover that data being brought in apologies if this has already been asked but i have not seen a clear answer from this subredditfrom what i have found on google thanks so much for any assistance
# 4  i am working with a dataset of patient performancedata and patient demographics for people with a medical condition i am trying to assess the effect of a treatment on the patients and as i am trying to replicate a randomized experiment from a observational study i am performing matching between the treatment and control group when i try to perform mahalanobis distance matching however i keep getting the following warning on matlab warning matrix is close to singular or badly scaled results may be inaccurate rcond e the warning was caused because the determinant of my covariance matrix was very close to so when i calculated the inverse of this matrix as i need to do for finding the mahalanobis distance the matrix element values become very close to as well after reading about this warning a little bit i found that when this warning is displayed the results of mahalanobis distance matching is not very reliable i thought this was because my matrix became very sparse after i introduced onehotencoding to split the multicategorical features into many different features and hence some of my new features were for category values that had very few occurrences less than to address this issue i got rid of the category values with very low occurrences less than or binned them together with other lowoccurrence category values into slightly larger bins so their chances of occurring increased and my datamatrix was less sparse so i reduced the number of features from to and i plotted the histograms for all my features to see their distributions and this is what it looked like note that the element values have been normalized to by subtracting the feature mean and then divided by the feature standard deviation it looked visually satisfactory to me but i still kept getting the same warning in matlab when i tried finding the determinant of my new covariance matrix it was still very small e in a further attempt to fix this issue i checked whether removing all of the categorical features if we consider the onehot encoded features made things any better by making the matrix less sparse the new featurehistogram looked like this this time when i tried mahalanobis distance matching the warning was removed because the determinant of the covariance matrix was larger e so i tried to see if i could include one of the removed multicategorical features without facing the same problem as these are important features i would prefer to include when doing my matching i added a categorical feature with possible values and all the values very well distributed see histogram below but alas simply including these new onehotencoded features seems to cause the determinant of the covariance matrix to become so small that i start getting the same warning in matlab is there any fix to this issue or is it simply impossible to reliably perform mahalanobis distance matching on this dataset without leaving out the multicategorical values
#
#                                                                                                                                                                                                                                                                                       ref_title  \
# 0  i want to transition into the data scienceanalyst or related field rather than asking whether i should choose a particular boootcamp or learn some language i would like to hear opinions on what path should i choose that will land me a job of some kind in the field as soon as possible
# 1                                                                                                                                                          psngram linguistic features for improving machine learning and deep learning model accuracy for the first time in python new release
# 2                                                                                                                                                                                                                                does anyone use any type of gradient smoothing for binned data
# 3                                                                                                                                                                                                                                               setting up a model for retraining in production
# 4                                                                                                                                                                                                     is mahalanobisdistance matching between points not compatible with onehotencoded datasets
#
#                                                                     candidate_title
# 0                    what is the best way to get a job in the field of data science
# 1                                                           python spacy for ngrams
# 2              what is the best way of calculating the weights for a neural network
# 3  what is the best way of storing a large amount of data in the retraining process
# 4                      how do i get the best results out of the mahalanobis dataset
